# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/Electronic_Police_Report_2018.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Mounted at /content/drive
#        Item_Number  District                 Location Disposition Signal_Type  \
# 0       C-17045-24         7    017XX Chimney Wood Dr      CLOSED          67
# 1       F-13967-18         8      XX French Market Pl      CLOSED         67E
# 2       F-13967-18         8      XX French Market Pl      CLOSED         67E
# 3       F-13967-18         8      XX French Market Pl      CLOSED         67E
# 4       I-18348-18         7        056XX Clements Dr      CLOSED         62R
# ...            ...       ...                      ...         ...         ...
# 125950  K-20725-18         4  021XX Springbrook Ln #M      CLOSED         67F
# 125951  K-20725-18         4  021XX Springbrook Ln #M      CLOSED         67F
# 125952  K-20725-18         4  021XX Springbrook Ln #M      CLOSED         67F
# 125953  A-10629-18         6    022XX Saint Andrew St      CLOSED          35
# 125954  C-25493-18         2          056XX Loyola Av      CLOSED          66
#
#                  Signal_Description       Occurred_Date_Time Charge_Code  \
# 0                             THEFT      2018-03-18 20:18:00       14 67
# 1                      EMBEZZLEMENT      2018-06-12 13:00:00  14 (27) 67
# 2                      EMBEZZLEMENT      2018-06-12 13:00:00         NaN
# 3                      EMBEZZLEMENT      2018-06-12 13:00:00         NaN
# 4       SIMPLE BURGLARY (RESIDENCE)      2018-09-15 11:58:00       14 62
# ...                             ...                      ...         ...
# 125950               THEFT BY FRAUD  2018-11-15 17:15:00.000     14 70.4
# 125951               THEFT BY FRAUD  2018-11-15 17:15:00.000       14 68
# 125952               THEFT BY FRAUD  2018-11-15 17:15:00.000       14 67
# 125953               SIMPLE BATTERY  2018-01-09 21:00:00.000         NaN
# 125954                      THREATS  2018-03-21 08:10:00.000       14 35
#
#                  Charge_Description Offender_Race  ... Offender_Age  \
# 0                             THEFT         BLACK  ...         22.0
# 1                   ATTEMPT - THEFT         WHITE  ...         44.0
# 2                               NaN         WHITE  ...         44.0
# 3                               NaN         WHITE  ...         44.0
# 4                   SIMPLE BURGLARY         BLACK  ...         30.0
# ...                             ...           ...  ...          ...
# 125950          ACCESS DEVICE FRAUD         BLACK  ...         27.0
# 125951  UNAUTHORIZED USE OF MOVABLE         BLACK  ...         27.0
# 125952                        THEFT         BLACK  ...         27.0
# 125953                          NaN         BLACK  ...         44.0
# 125954               SIMPLE BATTERY         BLACK  ...         16.0
#
#         Offender_Number  Person_Type  Victim_Race Victim_Gender Victim_Age  \
# 0                   1.0          NaN        BLACK        FEMALE       27.0
# 1                   1.0          NaN          NaN           NaN        NaN
# 2                   1.0          NaN        WHITE          MALE       61.0
# 3                   1.0          NaN          NaN           NaN        NaN
# 4                   1.0          NaN        BLACK        FEMALE       32.0
# ...                 ...          ...          ...           ...        ...
# 125950              1.0          NaN        BLACK        FEMALE       41.0
# 125951              1.0          NaN        BLACK        FEMALE       41.0
# 125952              1.0          NaN        BLACK        FEMALE       41.0
# 125953              1.0          NaN        BLACK        FEMALE       61.0
# 125954              1.0          NaN        BLACK        FEMALE       17.0
#
#         Victim_Number  Victim_Fatal_Status Hate_Crime  Report_Type
# 0                 1.0            Non-fatal        NaN          NaN
# 1                 1.0            Non-fatal        NaN          NaN
# 2                 2.0            Non-fatal        NaN          NaN
# 3                 3.0            Non-fatal        NaN          NaN
# 4                 1.0            Non-fatal        NaN          NaN
# ...               ...                  ...        ...          ...
# 125950            1.0            Non-fatal        NaN          NaN
# 125951            1.0            Non-fatal        NaN          NaN
# 125952            1.0            Non-fatal        NaN          NaN
# 125953            2.0            Non-fatal        NaN          NaN
# 125954            1.0            Non-fatal        NaN          NaN
#
# [125955 rows x 21 columns]

# %%
import pandas as pd
import re
import numpy as np

def find_address_column(df):
    address_pattern = re.compile(r'\b\d+\s+\w+\s+(?:way|place|drive|lane|street|avenue|road|boulevard|wy|pl|dr|ln|st|ave|rd|blvd||Wy|Pl|St|Ave|Rd|Blvd|Dr|Ln|DRIVE|WAY|PLACE|LANE|STREET|AVENUE|BOULEVARD|ROAD|ST|DR|LN|WY|PL|AVE|RD|Way|Place|Drive|Lane|Boulevard|Street|Avenue|Road)\b', re.IGNORECASE)
    for column in df.columns:
        if df[column].astype(str).str.contains(address_pattern).any():
            return column
    return None


address_column = find_address_column(df)
if address_column:
    print(f"Address column found: {address_column}")
else:
    print("No address column found.")
# Out:
# Address column found: Location

# %%
import pandas as pd
import re

# Dictionary mapping abbreviations to full names
abbreviation_map = {
    "St": "Street",
    "Ave": "Avenue",
    "Rd": "Road",
    "Blvd": "Boulevard",
    "Dr": "Drive",
    "Ln": "Lane",
    "Wy": "Way",
    "Pl": "Place"
}

# Function to replace abbreviations safely using regex with word boundaries
def expand_abbreviations(address):
    for abbr, full in abbreviation_map.items():
        address = re.sub(rf'\b{abbr}\b', full, address, flags=re.IGNORECASE)  # Replace full words only
    return address

# Apply function **only to first 10 rows**
df.loc[:9, address_column] = df.loc[:9, address_column].astype(str).apply(expand_abbreviations)

# Print results
print(df.head(10))  # Show first 10 rows to verify
# Out:
#   Item_Number  District                  Location Disposition Signal_Type  \
# 0  C-17045-24         7  017XX Chimney Wood Drive      CLOSED          67
# 1  F-13967-18         8    XX French Market Place      CLOSED         67E
# 2  F-13967-18         8    XX French Market Place      CLOSED         67E
# 3  F-13967-18         8    XX French Market Place      CLOSED         67E
# 4  I-18348-18         7      056XX Clements Drive      CLOSED         62R
# 5  K-37468-18         7        095XX Hayne Bd #10      CLOSED          62
# 6  G-20358-18         7          072XX Bundy Road      CLOSED         35D
# 7  G-23555-18         8     003XX Chartres Street      CLOSED          56
# 8  E-17092-18         7      086XX Dinkins Street      CLOSED         62C
# 9  B-12945-18         6        031XX Erato Street        OPEN         67A
#
#             Signal_Description   Occurred_Date_Time Charge_Code  \
# 0                        THEFT  2018-03-18 20:18:00       14 67
# 1                 EMBEZZLEMENT  2018-06-12 13:00:00  14 (27) 67
# 2                 EMBEZZLEMENT  2018-06-12 13:00:00         NaN
# 3                 EMBEZZLEMENT  2018-06-12 13:00:00         NaN
# 4  SIMPLE BURGLARY (RESIDENCE)  2018-09-15 11:58:00       14 62
# 5              SIMPLE BURGLARY  2018-11-28 16:45:00     14 62.8
# 6    SIMPLE BATTERY (DOMESTIC)  2018-07-17 00:18:00     14 35.3
# 7       SIMPLE CRIMINAL DAMAGE  2018-07-19 14:45:00      54 151
# 8    SIMPLE BURGLARY (VEHICLE)  2018-05-14 04:30:00     14 69.1
# 9                   AUTO THEFT  2018-02-11 14:00:00         NaN
#
#                       Charge_Description Offender_Race  ... Offender_Age  \
# 0                                  THEFT         BLACK  ...         22.0
# 1                        ATTEMPT - THEFT         WHITE  ...         44.0
# 2                                    NaN         WHITE  ...         44.0
# 3                                    NaN         WHITE  ...         44.0
# 4                        SIMPLE BURGLARY         BLACK  ...         30.0
# 5              RELATIVE TO HOME INVASION         BLACK  ...         58.0
# 6        DOMESTIC ABUSE BATTERY - SIMPLE         BLACK  ...         29.0
# 7            CRIMINAL DAMAGE TO PROPERTY         BLACK  ...         30.0
# 8  ILLEGAL POSSESSION OF STOLEN FIREARMS         BLACK  ...         29.0
# 9                                    NaN           NaN  ...          NaN
#
#    Offender_Number  Person_Type  Victim_Race Victim_Gender Victim_Age  \
# 0              1.0          NaN        BLACK        FEMALE       27.0
# 1              1.0          NaN          NaN           NaN        NaN
# 2              1.0          NaN        WHITE          MALE       61.0
# 3              1.0          NaN          NaN           NaN        NaN
# 4              1.0          NaN        BLACK        FEMALE       32.0
# 5              1.0          NaN        BLACK        FEMALE       47.0
# 6              1.0          NaN        BLACK        FEMALE       28.0
# 7              1.0          NaN          NaN           NaN        NaN
# 8              1.0          NaN        BLACK          MALE       23.0
# 9              NaN          NaN          NaN           NaN        NaN
#
#    Victim_Number  Victim_Fatal_Status Hate_Crime  Report_Type
# 0            1.0            Non-fatal        NaN          NaN
# 1            1.0            Non-fatal        NaN          NaN
# 2            2.0            Non-fatal        NaN          NaN
# 3            3.0            Non-fatal        NaN          NaN
# 4            1.0            Non-fatal        NaN          NaN
# 5            1.0            Non-fatal        NaN          NaN
# 6            1.0            Non-fatal        NaN          NaN
# 7            1.0            Non-fatal        NaN          NaN
# 8            1.0            Non-fatal        NaN          NaN
# 9            NaN            Non-fatal        NaN          NaN
#
# [10 rows x 21 columns]

# %%
import pandas as pd
import re

# Dictionary mapping full street names to abbreviations
full_to_abbreviation = {
    "Street": "St",
    "Avenue": "Ave",
    "Road": "Rd",
    "Boulevard": "Blvd",
    "Drive": "Dr",
    "Lane": "Ln",
    "Way": "Wy",
    "Place": "Pl"
}

# Function to abbreviate full street names (case-insensitive)
def abbreviate_address(address):
    for full_name, abbr in full_to_abbreviation.items():
        address = re.sub(rf'\b{full_name}\b', abbr, address, flags=re.IGNORECASE)  # Case-insensitive replacement
    return address

# Apply function **only to the last 10 rows**
df.loc[df.index[-10:], address_column] = df.loc[df.index[-10:], address_column].astype(str).apply(abbreviate_address)

# Print results
print(df.tail(10))  # Show last 10 rows to verify
# Out:
#        Item_Number  District                      Location Disposition  \
# 125945  J-14666-18         8  002XX Saint Charles Av #3206      CLOSED
# 125946  J-14666-18         8  002XX Saint Charles Av #3206      CLOSED
# 125947  K-23474-18         5                018XX Music St      CLOSED
# 125948  K-23474-18         5                018XX Music St      CLOSED
# 125949  K-23474-18         5                018XX Music St      CLOSED
# 125950  K-20725-18         4       021XX Springbrook Ln #M      CLOSED
# 125951  K-20725-18         4       021XX Springbrook Ln #M      CLOSED
# 125952  K-20725-18         4       021XX Springbrook Ln #M      CLOSED
# 125953  A-10629-18         6         022XX Saint Andrew St      CLOSED
# 125954  C-25493-18         2               056XX Loyola Av      CLOSED
#
#        Signal_Type  Signal_Description       Occurred_Date_Time Charge_Code  \
# 125945          67               THEFT  2018-05-12 09:33:00.000    14 67.16
# 125946          67               THEFT  2018-05-12 09:33:00.000       14 72
# 125947          37  AGGRAVATED ASSAULT  2018-11-17 18:08:00.000       14 37
# 125948          37  AGGRAVATED ASSAULT  2018-11-17 18:08:00.000       14 67
# 125949          37  AGGRAVATED ASSAULT  2018-11-17 18:08:00.000         NaN
# 125950         67F      THEFT BY FRAUD  2018-11-15 17:15:00.000     14 70.4
# 125951         67F      THEFT BY FRAUD  2018-11-15 17:15:00.000       14 68
# 125952         67F      THEFT BY FRAUD  2018-11-15 17:15:00.000       14 67
# 125953          35      SIMPLE BATTERY  2018-01-09 21:00:00.000         NaN
# 125954          66             THREATS  2018-03-21 08:10:00.000       14 35
#
#                  Charge_Description Offender_Race  ... Offender_Age  \
# 125945               IDENTITY THEFT         WHITE  ...         34.0
# 125946                      FORGERY         WHITE  ...         34.0
# 125947                 AGG. ASSAULT         BLACK  ...         34.0
# 125948                        THEFT         BLACK  ...         34.0
# 125949                          NaN         BLACK  ...         34.0
# 125950          ACCESS DEVICE FRAUD         BLACK  ...         27.0
# 125951  UNAUTHORIZED USE OF MOVABLE         BLACK  ...         27.0
# 125952                        THEFT         BLACK  ...         27.0
# 125953                          NaN         BLACK  ...         44.0
# 125954               SIMPLE BATTERY         BLACK  ...         16.0
#
#         Offender_Number  Person_Type  Victim_Race Victim_Gender Victim_Age  \
# 125945              1.0          NaN          NaN           NaN        NaN
# 125946              1.0          NaN          NaN           NaN        NaN
# 125947              1.0          NaN        BLACK          MALE       31.0
# 125948              1.0          NaN        BLACK          MALE       31.0
# 125949              1.0          NaN        BLACK        FEMALE       19.0
# 125950              1.0          NaN        BLACK        FEMALE       41.0
# 125951              1.0          NaN        BLACK        FEMALE       41.0
# 125952              1.0          NaN        BLACK        FEMALE       41.0
# 125953              1.0          NaN        BLACK        FEMALE       61.0
# 125954              1.0          NaN        BLACK        FEMALE       17.0
#
#         Victim_Number  Victim_Fatal_Status Hate_Crime  Report_Type
# 125945            1.0            Non-fatal        NaN          NaN
# 125946            1.0            Non-fatal        NaN          NaN
# 125947            1.0            Non-fatal        NaN          NaN
# 125948            1.0            Non-fatal        NaN          NaN
# 125949            2.0            Non-fatal        NaN          NaN
# 125950            1.0            Non-fatal        NaN          NaN
# 125951            1.0            Non-fatal        NaN          NaN
# 125952            1.0            Non-fatal        NaN          NaN
# 125953            2.0            Non-fatal        NaN          NaN
# 125954            1.0            Non-fatal        NaN          NaN
#
# [10 rows x 21 columns]

# %%
import pandas as pd
import re

# Dictionary mapping full street names to abbreviations
full_to_abbreviation = {
    "Street": "St",
    "Avenue": "Ave",
    "Road": "Rd",
    "Boulevard": "Blvd",
    "Drive": "Dr",
    "Lane": "Ln",
    "Way": "Wy",
    "Place": "Pl"
}

# Function to abbreviate full street names (case-insensitive)
def abbreviate_address(address):
    for full_name, abbr in full_to_abbreviation.items():
        address = re.sub(rf'\b{full_name}\b', abbr, address, flags=re.IGNORECASE)  # Case-insensitive replacement
    return address

# Apply function to the entire address column
df[address_column] = df[address_column].astype(str).apply(abbreviate_address)

# Print results
print(df[address_column].head(10))  # Show first 10 updated addresses
# Out:
# 0    017XX Chimney Wood Dr
# 1      XX French Market Pl
# 2      XX French Market Pl
# 3      XX French Market Pl
# 4        056XX Clements Dr
# 5       095XX Hayne Bd #10
# 6           072XX Bundy Rd
# 7        003XX Chartres St
# 8         086XX Dinkins St
# 9           031XX Erato St
# Name: Location, dtype: object

# %%
full_street_rows = df[df[address_column].str.contains('|'.join(full_to_abbreviation.keys()), case=False, regex=True)]
print(f"✅ After reprocessing, the column now has an abbreviated street address format. However, there are {len(full_street_rows)} addresses that are not updating due to typos, spacing, and unrecognizeable characters such as quotations, symbols etc. Consider updating these anomalies before using data set.")
print(f"If there are anomolies to the address column, examples will appear below:")
print(full_street_rows[[address_column]].head(10))  # Show sample of unchanged rows
# Out:
# ✅ After reprocessing, the column now has an abbreviated street address format. However, there are 3100 addresses that are not updating due to typos, spacing, and unrecognizeable characters such as quotations, symbols etc. Consider updating these anomalies before using data set.
# If there are anomolies to the address column, examples will appear below:
#                                   Location
# 34   S Broad St & Martin Luther King Jr Bd
# 96                    030XX Tulane Av #523
# 140                        028XX Tulane Av
# 141                        028XX Tulane Av
# 142                        039XX Tulane Av
# 190                        039XX Tulane Av
# 201                       007XX S Broad St
# 250                   030XX Tulane Av #523
# 251                       007XX S Broad St
# 282                        039XX Tulane Av

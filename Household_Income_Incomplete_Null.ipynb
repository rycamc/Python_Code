# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

path = '/content/drive/MyDrive/aggregate-household-income-in-the-past-12-months-in-2015-inflation-adjusted-dollars (1).csv'

import pandas as pd
df = pd.read_csv(path)
pd.set_option('display.max_columns', None)
df
# Out:
# Mounted at /content/drive
#            Neighborhood  Id  \
# 0      Allegheny Center   1
# 1        Allegheny West   2
# 2             Allentown   3
# 3             Arlington   4
# 4     Arlington Heights   5
# ..                  ...  ..
# 86  Upper Lawrenceville  87
# 87             West End  88
# 88         West Oakland  89
# 89             Westwood  90
# 90              Windgap  91
#
#     Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)  \
# 0                                          39947000.0
# 1                                          23793300.0
# 2                                          38303700.0
# 3                                          35349900.0
# 4                                           2389600.0
# ..                                                ...
# 86                                         65738500.0
# 87                                          3615800.0
# 88                                         16339500.0
# 89                                         91857100.0
# 90                                         34609300.0
#
#     Margin of Error; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)
# 0                                        6.437773e+06
# 1                                        2.202594e+07
# 2                                        7.490207e+06
# 3                                        6.140663e+06
# 4                                        1.162393e+06
# ..                                                ...
# 86                                       1.600713e+07
# 87                                       2.204875e+06
# 88                                       3.412753e+06
# 89                                       1.130450e+07
# 90                                       6.432817e+06
#
# [91 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

missing_counts = df.isnull().sum()
plt.figure(figsize=(8, 6))
missing_counts.plot(kind='bar')
plt.title('Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.show()
null_counts = df.isnull().sum()

for col, count in null_counts.items():
    if count > 0:
        print(f"Column '{col}' has {count} null values. Data is incomplete.")
# Out:
# Column 'Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)' has 2 null values. Data is incomplete.
# Column 'Margin of Error; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)' has 2 null values. Data is incomplete.

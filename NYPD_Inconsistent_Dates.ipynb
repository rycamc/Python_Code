# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/NYPD_Arrest_Data__Year_to_Date_.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Mounted at /content/drive
#        ARREST_KEY ARREST_DATE  PD_CD  \
# 0       298874520  01/04/2025    439
# 1       298799078  01/02/2025    101
# 2       298921520  01/05/2025    779
# 3       299008265  01/07/2025    105
# 4       298969999  01/06/2025    793
# ...           ...         ...    ...
# 71237   303938395  03/31/2025    729
# 71238   303885891  03/30/2025    478
# 71239   303937884  03/31/2025    439
# 71240   303887215  03/30/2025    478
# 71241   303934479  03/31/2025    268
#
#                                          PD_DESC  KY_CD  \
# 0      LARCENY,GRAND FROM OPEN AREAS, UNATTENDED  109.0
# 1                                      ASSAULT 3  344.0
# 2                 PUBLIC ADMINISTRATION,UNCLASSI  126.0
# 3                              STRANGULATION 1ST  106.0
# 4                           WEAPONS POSSESSION 3  118.0
# ...                                          ...    ...
# 71237             FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 71238             THEFT OF SERVICES, UNCLASSIFIE  343.0
# 71239  LARCENY,GRAND FROM OPEN AREAS, UNATTENDED  109.0
# 71240             THEFT OF SERVICES, UNCLASSIFIE  343.0
# 71241                         CRIMINAL MIS 2 & 3  121.0
#
#                              OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                        GRAND LARCENY  PL 1553004          F           M
# 1         ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           M
# 2              MISCELLANEOUS PENAL LAW  PL 215510B          F           K
# 3                       FELONY ASSAULT  PL 1211200          F           Q
# 4                    DANGEROUS WEAPONS  PL 2650201          F           M
# ...                                ...         ...        ...         ...
# 71237                          FORGERY  PL 1702500          F           M
# 71238  OTHER OFFENSES RELATED TO THEFT  PL 1651503          M           B
# 71239                    GRAND LARCENY  PL 1553501          F           M
# 71240  OTHER OFFENSES RELATED TO THEFT  PL 1651503          M           B
# 71241   CRIMINAL MISCHIEF & RELATED OF  PL 1450502          F           Q
#
#        ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0                    7                  0     25-44        M           BLACK
# 1                   23                  0     25-44        F           BLACK
# 2                   76                  0     45-64        M           WHITE
# 3                  113                  0     45-64        M           BLACK
# 4                    5                 73     25-44        M           WHITE
# ...                ...                ...       ...      ...             ...
# 71237               34                  0     18-24        M  BLACK HISPANIC
# 71238               43                  1     18-24        F           BLACK
# 71239               13                  0     25-44        M  WHITE HISPANIC
# 71240               47                  1     25-44        M           BLACK
# 71241              103                  0     25-44        M           BLACK
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0               0           0   0.000000   0.000000
# 1         1000213      228833  40.794755 -73.942348
# 2               0           0   0.000000   0.000000
# 3         1046399      187126  40.680086 -73.775931
# 4          983907      199958  40.715526 -74.001238
# ...           ...         ...        ...        ...
# 71237     1004367      254624  40.865536 -73.927268
# 71238     1022565      242793  40.833003 -73.861542
# 71239      988986      207106  40.735143 -73.982909
# 71240     1022187      261218  40.883576 -73.862804
# 71241     1046499      197760  40.709273 -73.775469
#
#                           New Georeferenced Column
# 0                                      POINT (0 0)
# 1      POINT (-73.9423482609703 40.79475532416718)
# 2                                      POINT (0 0)
# 3                     POINT (-73.775931 40.680086)
# 4                     POINT (-74.001238 40.715526)
# ...                                            ...
# 71237              POINT (-73.9272684 40.86553571)
# 71238              POINT (-73.8615425 40.83300293)
# 71239                 POINT (-73.982909 40.735143)
# 71240              POINT (-73.86280418 40.8835756)
# 71241                 POINT (-73.775469 40.709273)
#
# [71242 rows x 19 columns]

# %%
import pandas as pd

def find_date_column(df):
    possible_date_cols = []

    for col in df.columns:
        try:
            parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
            valid_dates = parsed.notna().sum() / len(df)  # Percentage of valid entries

            # Ensure column was originally non-numeric before conversion
            is_object_or_string = df[col].dtype == "object" or pd.api.types.is_string_dtype(df[col])

            print(f"🔎 Checking '{col}': {valid_dates:.2%} valid dates | Type: {df[col].dtype}")  # Debugging

            if valid_dates > 0.6 and is_object_or_string:  # At least 60% valid dates & originally text-based
                possible_date_cols.append(col)
        except Exception as e:
            print(f"⚠️ Error processing '{col}': {e}")

    return possible_date_cols[0] if possible_date_cols else None

# Example usage:
date_col = find_date_column(df)
print(f"📅 Detected date column: {date_col}" if date_col else "❌ No date column detected!")
# Out:
# 🔎 Checking 'ARREST_KEY': 100.00% valid dates | Type: int64
# 🔎 Checking 'ARREST_DATE': 100.00% valid dates | Type: object
# 🔎 Checking 'PD_CD': 100.00% valid dates | Type: int64
# 🔎 Checking 'PD_DESC': 0.00% valid dates | Type: object
# 🔎 Checking 'KY_CD': 99.99% valid dates | Type: float64
# 🔎 Checking 'OFNS_DESC': 0.00% valid dates | Type: object
# 🔎 Checking 'LAW_CODE': 0.00% valid dates | Type: object
# 🔎 Checking 'LAW_CAT_CD': 0.00% valid dates | Type: object
# 🔎 Checking 'ARREST_BORO': 0.00% valid dates | Type: object
# 🔎 Checking 'ARREST_PRECINCT': 100.00% valid dates | Type: int64
# 🔎 Checking 'JURISDICTION_CODE': 100.00% valid dates | Type: int64
# 🔎 Checking 'AGE_GROUP': 0.00% valid dates | Type: object
# 🔎 Checking 'PERP_SEX': 0.00% valid dates | Type: object
# 🔎 Checking 'PERP_RACE': 0.00% valid dates | Type: object
# 🔎 Checking 'X_COORD_CD': 100.00% valid dates | Type: int64
# 🔎 Checking 'Y_COORD_CD': 100.00% valid dates | Type: int64
# 🔎 Checking 'Latitude': 100.00% valid dates | Type: float64
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# 🔎 Checking 'Longitude': 100.00% valid dates | Type: float64
# 🔎 Checking 'New Georeferenced Column': 0.00% valid dates | Type: object
# 📅 Detected date column: ARREST_DATE

# %%
df.loc[df.index[-50:], date_col] = pd.to_datetime(df[date_col], errors='coerce').dt.strftime('%B %d, %Y')

print(df)

count_written = df[date_col].astype(str).str.match(r'^[A-Za-z]+ \d{1,2}, \d{4}$').sum()
print(f"{count_written} dates are in written format! This data is inconsistent. Consider makeing entire {date_col} column the same format.")
# Out:
#        ARREST_KEY     ARREST_DATE  PD_CD  \
# 0       298874520      01/04/2025    439
# 1       298799078      01/02/2025    101
# 2       298921520      01/05/2025    779
# 3       299008265      01/07/2025    105
# 4       298969999      01/06/2025    793
# ...           ...             ...    ...
# 71237   303938395  March 31, 2025    729
# 71238   303885891  March 30, 2025    478
# 71239   303937884  March 31, 2025    439
# 71240   303887215  March 30, 2025    478
# 71241   303934479  March 31, 2025    268
#
#                                          PD_DESC  KY_CD  \
# 0      LARCENY,GRAND FROM OPEN AREAS, UNATTENDED  109.0
# 1                                      ASSAULT 3  344.0
# 2                 PUBLIC ADMINISTRATION,UNCLASSI  126.0
# 3                              STRANGULATION 1ST  106.0
# 4                           WEAPONS POSSESSION 3  118.0
# ...                                          ...    ...
# 71237             FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 71238             THEFT OF SERVICES, UNCLASSIFIE  343.0
# 71239  LARCENY,GRAND FROM OPEN AREAS, UNATTENDED  109.0
# 71240             THEFT OF SERVICES, UNCLASSIFIE  343.0
# 71241                         CRIMINAL MIS 2 & 3  121.0
#
#                              OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                        GRAND LARCENY  PL 1553004          F           M
# 1         ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           M
# 2              MISCELLANEOUS PENAL LAW  PL 215510B          F           K
# 3                       FELONY ASSAULT  PL 1211200          F           Q
# 4                    DANGEROUS WEAPONS  PL 2650201          F           M
# ...                                ...         ...        ...         ...
# 71237                          FORGERY  PL 1702500          F           M
# 71238  OTHER OFFENSES RELATED TO THEFT  PL 1651503          M           B
# 71239                    GRAND LARCENY  PL 1553501          F           M
# 71240  OTHER OFFENSES RELATED TO THEFT  PL 1651503          M           B
# 71241   CRIMINAL MISCHIEF & RELATED OF  PL 1450502          F           Q
#
#        ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0                    7                  0     25-44        M           BLACK
# 1                   23                  0     25-44        F           BLACK
# 2                   76                  0     45-64        M           WHITE
# 3                  113                  0     45-64        M           BLACK
# 4                    5                 73     25-44        M           WHITE
# ...                ...                ...       ...      ...             ...
# 71237               34                  0     18-24        M  BLACK HISPANIC
# 71238               43                  1     18-24        F           BLACK
# 71239               13                  0     25-44        M  WHITE HISPANIC
# 71240               47                  1     25-44        M           BLACK
# 71241              103                  0     25-44        M           BLACK
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0               0           0   0.000000   0.000000
# 1         1000213      228833  40.794755 -73.942348
# 2               0           0   0.000000   0.000000
# 3         1046399      187126  40.680086 -73.775931
# 4          983907      199958  40.715526 -74.001238
# ...           ...         ...        ...        ...
# 71237     1004367      254624  40.865536 -73.927268
# 71238     1022565      242793  40.833003 -73.861542
# 71239      988986      207106  40.735143 -73.982909
# 71240     1022187      261218  40.883576 -73.862804
# 71241     1046499      197760  40.709273 -73.775469
#
#                           New Georeferenced Column
# 0                                      POINT (0 0)
# 1      POINT (-73.9423482609703 40.79475532416718)
# 2                                      POINT (0 0)
# 3                     POINT (-73.775931 40.680086)
# 4                     POINT (-74.001238 40.715526)
# ...                                            ...
# 71237              POINT (-73.9272684 40.86553571)
# 71238              POINT (-73.8615425 40.83300293)
# 71239                 POINT (-73.982909 40.735143)
# 71240              POINT (-73.86280418 40.8835756)
# 71241                 POINT (-73.775469 40.709273)
#
# [71242 rows x 19 columns]
# 50 dates are in written format! This data is inconsistent. Consider makeing entire ARREST_DATE column the same format.

# %%
def format_date_columns(df, date_cols, format_string):
    # Ensure date_cols is a list even if a single column name is passed as a string
    if isinstance(date_cols, str):
        date_cols = [date_cols]

    for col in date_cols:
      # Use errors='coerce' in to_datetime to handle potential parsing issues
      df[col] = pd.to_datetime(df[col], errors='coerce', format='mixed').dt.strftime(format_string)
    return df

format_string = '%Y-%m-%d' # Desired output format

# Pass date_col as a list containing the column name
df = format_date_columns(df, date_col, format_string)
print(df)

count_written = df[date_col].astype(str).str.match(r'^[A-Za-z]+ \d{1,2}, \d{4}$').sum()

print(f"{count_written} dates are in written format! {date_col} column is now in the same format. This data is now consistent.")
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD  \
# 0       298874520  2025-01-04    439
# 1       298799078  2025-01-02    101
# 2       298921520  2025-01-05    779
# 3       299008265  2025-01-07    105
# 4       298969999  2025-01-06    793
# ...           ...         ...    ...
# 71237   303938395  2025-03-31    729
# 71238   303885891  2025-03-30    478
# 71239   303937884  2025-03-31    439
# 71240   303887215  2025-03-30    478
# 71241   303934479  2025-03-31    268
#
#                                          PD_DESC  KY_CD  \
# 0      LARCENY,GRAND FROM OPEN AREAS, UNATTENDED  109.0
# 1                                      ASSAULT 3  344.0
# 2                 PUBLIC ADMINISTRATION,UNCLASSI  126.0
# 3                              STRANGULATION 1ST  106.0
# 4                           WEAPONS POSSESSION 3  118.0
# ...                                          ...    ...
# 71237             FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 71238             THEFT OF SERVICES, UNCLASSIFIE  343.0
# 71239  LARCENY,GRAND FROM OPEN AREAS, UNATTENDED  109.0
# 71240             THEFT OF SERVICES, UNCLASSIFIE  343.0
# 71241                         CRIMINAL MIS 2 & 3  121.0
#
#                              OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                        GRAND LARCENY  PL 1553004          F           M
# 1         ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           M
# 2              MISCELLANEOUS PENAL LAW  PL 215510B          F           K
# 3                       FELONY ASSAULT  PL 1211200          F           Q
# 4                    DANGEROUS WEAPONS  PL 2650201          F           M
# ...                                ...         ...        ...         ...
# 71237                          FORGERY  PL 1702500          F           M
# 71238  OTHER OFFENSES RELATED TO THEFT  PL 1651503          M           B
# 71239                    GRAND LARCENY  PL 1553501          F           M
# 71240  OTHER OFFENSES RELATED TO THEFT  PL 1651503          M           B
# 71241   CRIMINAL MISCHIEF & RELATED OF  PL 1450502          F           Q
#
#        ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0                    7                  0     25-44        M           BLACK
# 1                   23                  0     25-44        F           BLACK
# 2                   76                  0     45-64        M           WHITE
# 3                  113                  0     45-64        M           BLACK
# 4                    5                 73     25-44        M           WHITE
# ...                ...                ...       ...      ...             ...
# 71237               34                  0     18-24        M  BLACK HISPANIC
# 71238               43                  1     18-24        F           BLACK
# 71239               13                  0     25-44        M  WHITE HISPANIC
# 71240               47                  1     25-44        M           BLACK
# 71241              103                  0     25-44        M           BLACK
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0               0           0   0.000000   0.000000
# 1         1000213      228833  40.794755 -73.942348
# 2               0           0   0.000000   0.000000
# 3         1046399      187126  40.680086 -73.775931
# 4          983907      199958  40.715526 -74.001238
# ...           ...         ...        ...        ...
# 71237     1004367      254624  40.865536 -73.927268
# 71238     1022565      242793  40.833003 -73.861542
# 71239      988986      207106  40.735143 -73.982909
# 71240     1022187      261218  40.883576 -73.862804
# 71241     1046499      197760  40.709273 -73.775469
#
#                           New Georeferenced Column
# 0                                      POINT (0 0)
# 1      POINT (-73.9423482609703 40.79475532416718)
# 2                                      POINT (0 0)
# 3                     POINT (-73.775931 40.680086)
# 4                     POINT (-74.001238 40.715526)
# ...                                            ...
# 71237              POINT (-73.9272684 40.86553571)
# 71238              POINT (-73.8615425 40.83300293)
# 71239                 POINT (-73.982909 40.735143)
# 71240              POINT (-73.86280418 40.8835756)
# 71241                 POINT (-73.775469 40.709273)
#
# [71242 rows x 19 columns]
# 0 dates are in written format! ARREST_DATE column is now in the same format. This data is now consistent.

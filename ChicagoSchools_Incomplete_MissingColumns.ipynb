# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/Chicago_Public_Schools_-_School_Admissions_Information_SY2324.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      School_ID       Short_Name  \
# 0       610026           KINZIE
# 1       610078   INTER-AMERICAN
# 2       609756         CURIE HS
# 3       609756         CURIE HS
# 4       610039        VON LINNE
# ..         ...              ...
# 930     609738  LINCOLN PARK HS
# 931     610073         MITCHELL
# 932     610518    AUSTIN CCA HS
# 933     610041          LOCKE J
# 934     610369        JACKSON M
#
#                                            Long_Name Primary_Category  \
# 0                    John H Kinzie Elementary School               ES
# 1            Inter-American Elementary Magnet School               ES
# 2    Marie Sklodowska Curie Metropolitan High School               HS
# 3    Marie Sklodowska Curie Metropolitan High School               HS
# 4                   Carl von Linne Elementary School               ES
# ...

# %%
import pandas as pd

df_remove = df

def readd_first_three_cols(df_remove):
    # Store the first 3 columns
    first_three_cols = df_remove.iloc[:, :3]

    # Delete the first 3 columns
    df_remove = df_remove.iloc[:, 3:]

    return df_remove

print("Original DataFrame:")
print(df)

df_remove = readd_first_three_cols(df_remove)
print("\nDataFrame with first 3 columns deleted:")
print(df_remove)
# Out:
# Original DataFrame:
#      School_ID       Short_Name  \
# 0       610026           KINZIE
# 1       610078   INTER-AMERICAN
# 2       609756         CURIE HS
# 3       609756         CURIE HS
# 4       610039        VON LINNE
# ..         ...              ...
# 930     609738  LINCOLN PARK HS
# 931     610073         MITCHELL
# 932     610518    AUSTIN CCA HS
# 933     610041          LOCKE J
# 934     610369        JACKSON M
#
#                                            Long_Name Primary_Category  \
# 0                    John H Kinzie Elementary School               ES
# 1            Inter-American Elementary Magnet School               ES
# 2    Marie Sklodowska Curie Metropolitan High School               HS
# 3    Marie Sklodowska Curie Metropolitan High School               HS
# 4                   Carl von Linne Elementary School               ES
# ..                                               ...              ...
# ...

# %%
def compare_columns(df, df_remove):
    """
    Compares the columns of two DataFrames and prints the differences.

    Args:
        df1: The first DataFrame.
        df2: The second DataFrame.
    """
    cols1 = set(df.columns)
    cols2 = set(df_remove.columns)

    added_cols = cols2 - cols1
    removed_cols = cols1 - cols2
    common_cols = cols1.intersection(cols2)

    print("Columns missing that are needed to answer query:", removed_cols)



compare_columns(df, df_remove)
# Out:
# Columns missing that are needed to answer query: {'Long_Name', 'School_ID', 'Short_Name'}

# %%
# List of required column names
required_columns =  df.iloc[:, :3]

# Check for missing columns and print a message
missing_columns = [col for col in required_columns if col not in df.columns]

if missing_columns:
    print(f"Error: The following required columns are missing from the DataFrame: {missing_columns}")
else:
    print("All required columns are now present in the DataFrame. The query can be answered.")
# Out:
# All required columns are now present in the DataFrame. The query can be answered.

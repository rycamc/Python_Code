# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/Natural_Turf_Maintenance.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Mounted at /content/drive
#                            id  DateofWork    Borough District  \
# 0           296_NTD1_20240501  05/01/2024  Manhattan     M-15
# 1           297_NTD1_20240501  05/01/2024  Manhattan     M-03
# 2           299_NTD1_20240501  05/01/2024  Manhattan     M-09
# 3           300_NTD1_20240501  05/01/2024      Bronx     X-11
# 4           306_NTD1_20240501  05/01/2024     Queens     Q-02
# ...                       ...         ...        ...      ...
# 42814  15106_2021NTD_20211015  10/15/2021      Bronx     X-10
# 42815  15107_2021NTD_20211015  10/15/2021      Bronx     X-10
# 42816  15108_2021NTD_20211015  10/15/2021      Bronx     X-10
# 42817  15109_2021NTD_20211015  10/15/2021      Bronx     X-10
# 42818  15110_2021NTD_20211015  10/15/2021      Bronx     X-10
#
#                                                Site Name   OMPPropID  \
# 0                            East River Esplanade Zone 4  M108T-ZN04
# 1                                   Tompkins Square Park        M088
# 2                             Jacob H. Schiff Playground        M223
# 3      Bronx & Pelham Pkwy(2.5 Miles)-Pelham Parkway ...   X003-ZN01
# 4                                        Gordon Triangle        Q018
# ...                                                  ...         ...
# 42814                            Ferry Point Park Zone 2   X126-ZN02
# 42815                Bicentennial Veterans Memorial Park       X191A
# 42816           Thrg Nck Exwy & Pennyfield Av & Miles Av       XZ392
# 42817                          Schley & Ellsworth Site 2       XZ393
# 42818                          Shcley & Ellsworth site 1       XZ394
#
#          StartTime      EndTime  CrewSize MowingResponse TrimmingResponse  \
# 0       8:00:00 AM   2:00:00 PM       3.0            Yes              Yes
# 1      10:00:00 AM  10:45:00 AM       2.0            Yes               No
# 2       3:00:00 PM   6:00:00 PM       3.0            Yes              Yes
# 3       6:00:00 AM  12:00:00 PM       3.0             No              Yes
# 4      10:15:00 AM  12:30:00 PM       2.0            Yes              Yes
# ...            ...          ...       ...            ...              ...
# 42814   4:30:00 PM   6:30:00 PM       4.0            NaN              NaN
# 42815  11:00:00 AM   2:30:00 PM       1.0            NaN              NaN
# 42816   8:15:00 AM   9:00:00 AM       1.0            NaN              NaN
# 42817   9:30:00 AM  10:15:00 AM       1.0            NaN              NaN
# 42818  10:15:00 AM  10:45:00 AM       1.0            NaN              NaN
#
#       BlowingResponse  AbleToCompleteAssignedTasks ReasonForIncomplete
# 0                 Yes                         True                 NaN
# 1                  No                         True                 NaN
# 2                 Yes                         True                 NaN
# 3                 Yes                        False                 EOD
# 4                 Yes                         True                 NaN
# ...               ...                          ...                 ...
# 42814             NaN                         True                 NaN
# 42815             NaN                        False                 NaN
# 42816             NaN                         True                 NaN
# 42817             NaN                         True                 NaN
# 42818             NaN                         True                 NaN
#
# [42819 rows x 14 columns]

# %%
import pandas as pd

df_remove = df

def readd_first_three_cols(df_remove):
    # Store the first 3 columns
    first_three_cols = df_remove.iloc[:, :3]

    # Delete the first 3 columns
    df_remove = df_remove.iloc[:, 3:]

    return df_remove

print("Original DataFrame:")
print(df)

df_remove = readd_first_three_cols(df_remove)
print("\nDataFrame with first 3 columns deleted:")
print(df_remove)
# Out:
# Original DataFrame:
#                            id  DateofWork    Borough District  \
# 0           296_NTD1_20240501  05/01/2024  Manhattan     M-15
# 1           297_NTD1_20240501  05/01/2024  Manhattan     M-03
# 2           299_NTD1_20240501  05/01/2024  Manhattan     M-09
# 3           300_NTD1_20240501  05/01/2024      Bronx     X-11
# 4           306_NTD1_20240501  05/01/2024     Queens     Q-02
# ...                       ...         ...        ...      ...
# 42814  15106_2021NTD_20211015  10/15/2021      Bronx     X-10
# 42815  15107_2021NTD_20211015  10/15/2021      Bronx     X-10
# 42816  15108_2021NTD_20211015  10/15/2021      Bronx     X-10
# 42817  15109_2021NTD_20211015  10/15/2021      Bronx     X-10
# 42818  15110_2021NTD_20211015  10/15/2021      Bronx     X-10
#
#                                                Site Name   OMPPropID  \
# 0                            East River Esplanade Zone 4  M108T-ZN04
# 1                                   Tompkins Square Park        M088
# 2                             Jacob H. Schiff Playground        M223
# 3      Bronx & Pelham Pkwy(2.5 Miles)-Pelham Parkway ...   X003-ZN01
# 4                                        Gordon Triangle        Q018
# ...                                                  ...         ...
# 42814                            Ferry Point Park Zone 2   X126-ZN02
# 42815                Bicentennial Veterans Memorial Park       X191A
# 42816           Thrg Nck Exwy & Pennyfield Av & Miles Av       XZ392
# 42817                          Schley & Ellsworth Site 2       XZ393
# 42818                          Shcley & Ellsworth site 1       XZ394
#
#          StartTime      EndTime  CrewSize MowingResponse TrimmingResponse  \
# 0       8:00:00 AM   2:00:00 PM       3.0            Yes              Yes
# 1      10:00:00 AM  10:45:00 AM       2.0            Yes               No
# 2       3:00:00 PM   6:00:00 PM       3.0            Yes              Yes
# 3       6:00:00 AM  12:00:00 PM       3.0             No              Yes
# 4      10:15:00 AM  12:30:00 PM       2.0            Yes              Yes
# ...            ...          ...       ...            ...              ...
# 42814   4:30:00 PM   6:30:00 PM       4.0            NaN              NaN
# 42815  11:00:00 AM   2:30:00 PM       1.0            NaN              NaN
# 42816   8:15:00 AM   9:00:00 AM       1.0            NaN              NaN
# 42817   9:30:00 AM  10:15:00 AM       1.0            NaN              NaN
# 42818  10:15:00 AM  10:45:00 AM       1.0            NaN              NaN
#
#       BlowingResponse  AbleToCompleteAssignedTasks ReasonForIncomplete
# 0                 Yes                         True                 NaN
# 1                  No                         True                 NaN
# 2                 Yes                         True                 NaN
# 3                 Yes                        False                 EOD
# 4                 Yes                         True                 NaN
# ...               ...                          ...                 ...
# 42814             NaN                         True                 NaN
# 42815             NaN                        False                 NaN
# 42816             NaN                         True                 NaN
# 42817             NaN                         True                 NaN
# 42818             NaN                         True                 NaN
#
# [42819 rows x 14 columns]
#
# DataFrame with first 3 columns deleted:
#       District                                          Site Name   OMPPropID  \
# 0         M-15                        East River Esplanade Zone 4  M108T-ZN04
# 1         M-03                               Tompkins Square Park        M088
# 2         M-09                         Jacob H. Schiff Playground        M223
# 3         X-11  Bronx & Pelham Pkwy(2.5 Miles)-Pelham Parkway ...   X003-ZN01
# 4         Q-02                                    Gordon Triangle        Q018
# ...        ...                                                ...         ...
# 42814     X-10                            Ferry Point Park Zone 2   X126-ZN02
# 42815     X-10                Bicentennial Veterans Memorial Park       X191A
# 42816     X-10           Thrg Nck Exwy & Pennyfield Av & Miles Av       XZ392
# 42817     X-10                          Schley & Ellsworth Site 2       XZ393
# 42818     X-10                          Shcley & Ellsworth site 1       XZ394
#
#          StartTime      EndTime  CrewSize MowingResponse TrimmingResponse  \
# 0       8:00:00 AM   2:00:00 PM       3.0            Yes              Yes
# 1      10:00:00 AM  10:45:00 AM       2.0            Yes               No
# 2       3:00:00 PM   6:00:00 PM       3.0            Yes              Yes
# 3       6:00:00 AM  12:00:00 PM       3.0             No              Yes
# 4      10:15:00 AM  12:30:00 PM       2.0            Yes              Yes
# ...            ...          ...       ...            ...              ...
# 42814   4:30:00 PM   6:30:00 PM       4.0            NaN              NaN
# 42815  11:00:00 AM   2:30:00 PM       1.0            NaN              NaN
# 42816   8:15:00 AM   9:00:00 AM       1.0            NaN              NaN
# 42817   9:30:00 AM  10:15:00 AM       1.0            NaN              NaN
# 42818  10:15:00 AM  10:45:00 AM       1.0            NaN              NaN
#
#       BlowingResponse  AbleToCompleteAssignedTasks ReasonForIncomplete
# 0                 Yes                         True                 NaN
# 1                  No                         True                 NaN
# 2                 Yes                         True                 NaN
# 3                 Yes                        False                 EOD
# 4                 Yes                         True                 NaN
# ...               ...                          ...                 ...
# 42814             NaN                         True                 NaN
# 42815             NaN                        False                 NaN
# 42816             NaN                         True                 NaN
# 42817             NaN                         True                 NaN
# 42818             NaN                         True                 NaN
#
# [42819 rows x 11 columns]

# %%
def compare_columns(df, df_remove):
    """
    Compares the columns of two DataFrames and prints the differences.

    Args:
        df1: The first DataFrame.
        df2: The second DataFrame.
    """
    cols1 = set(df.columns)
    cols2 = set(df_remove.columns)

    added_cols = cols2 - cols1
    removed_cols = cols1 - cols2
    common_cols = cols1.intersection(cols2)

    print("Columns missing that are needed to answer query:", removed_cols)



compare_columns(df, df_remove)
# Out:
# Columns missing that are needed to answer query: {'id', 'Borough', 'DateofWork'}

# %%
# List of required column names
required_columns =  df.iloc[:, :3]

# Check for missing columns and print a message
missing_columns = [col for col in required_columns if col not in df.columns]

if missing_columns:
    print(f"Error: The following required columns are missing from the DataFrame: {missing_columns}")
else:
    print("All required columns are now present in the DataFrame. The query can be answered.")
# Out:
# All required columns are now present in the DataFrame. The query can be answered.

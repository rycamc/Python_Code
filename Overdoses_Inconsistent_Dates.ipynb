# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/Accidental_Drug_Related_Deaths_2012-2023.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Mounted at /content/drive
#              Date      Date Type   Age   Sex                       Race  \
# 0      01/02/2023  Date of death  65.0  Male                      White
# 1      01/18/2023  Date of death  42.0  Male                      White
# 2      01/26/2022  Date of death  34.0  Male                      White
# 3      02/04/2023  Date of death  34.0  Male                      White
# 4      02/18/2022  Date of death  43.0  Male                      White
# ...           ...            ...   ...   ...                        ...
# 11976  10/19/2021  Date of death  56.0  Male  Black or African American
# 11977  05/04/2021  Date of death  48.0  Male  Black or African American
# 11978  05/15/2021  Date of death  59.0  Male                      White
# 11979  05/28/2021  Date of death  68.0  Male  Black or African American
# 11980  12/24/2021  Date of death  29.0  Male                      White
#
#                              Ethnicity Residence City Residence County  \
# 0      No, not Spanish/Hispanic/Latino     BRIDGEPORT        FAIRFIELD
# 1      No, not Spanish/Hispanic/Latino      WATERBURY        NEW HAVEN
# 2                                  NaN     BROOKFIELD        FAIRFIELD
# 3                                  NaN            NaN              NaN
# 4                                  NaN        NORWICH       NEW LONDON
# ...                                ...            ...              ...
# 11976                              NaN       STAMFORD        FAIRFIELD
# 11977                              NaN     WEST HAVEN        NEW HAVEN
# 11978                              NaN   WETHERSFIELD         HARTFORD
# 11979                              NaN       HARTFORD         HARTFORD
# 11980      Not Spanish/Hispanic/Latino        SEYMOUR        NEW HAVEN
#
#       Residence State   Injury City  ... Xylazine Gabapentin Opiate NOS  \
# 0                  CT    BRIDGEPORT  ...      NaN        NaN        NaN
# 1                  CT    FARMINGTON  ...      NaN        NaN        NaN
# 2                  CT    BROOKFIELD  ...        Y        NaN        NaN
# 3                 NaN     NEW HAVEN  ...      NaN        NaN        NaN
# 4                  CT       NORWICH  ...      NaN        NaN        NaN
# ...               ...           ...  ...      ...        ...        ...
# 11976              CT      STAMFORD  ...      NaN        NaN        NaN
# 11977              CT    WEST HAVEN  ...      NaN        NaN        NaN
# 11978              CT  WETHERSFIELD  ...      NaN          Y        NaN
# 11979              CT      HARTFORD  ...      NaN        NaN        NaN
# 11980              CT       SEYMOUR  ...        Y        NaN        NaN
#
#       Heroin/Morph/Codeine Other Opioid Any Opioid Other  \
# 0                      NaN          NaN          Y   NaN
# 1                      NaN          NaN          Y   NaN
# 2                        Y          NaN          Y   NaN
# 3                      NaN          NaN          Y   NaN
# 4                      NaN          NaN          Y   NaN
# ...                    ...          ...        ...   ...
# 11976                  NaN          NaN          Y   PCP
# 11977                  NaN          NaN        NaN   NaN
# 11978                  NaN          NaN        NaN   NaN
# 11979                  NaN          NaN        NaN   NaN
# 11980                  NaN          NaN          Y   NaN
#
#                                         ResidenceCityGeo  \
# 0                BRIDGEPORT, CT\n(41.179195, -73.189476)
# 1               WATERBURY, CT\n(41.5542609, -73.0430692)
# 2      BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 3                       CT\n(41.57350273, -72.738305908)
# 4      NORWICH, CT\n(41.526760000000024, -72.07567999...
# ...                                                  ...
# 11976              STAMFORD, CT\n(41.051924, -73.539475)
# 11977            WEST HAVEN, CT\n(41.272336, -72.949817)
# 11978          WETHERSFIELD, CT\n(41.712487, -72.663607)
# 11979              HARTFORD, CT\n(41.765775, -72.673356)
# 11980               SEYMOUR, CT\n(41.395594, -73.073581)
#
#                                            InjuryCityGeo  \
# 0                BRIDGEPORT, CT\n(41.179195, -73.189476)
# 1               FARMINGTON, CT\n(41.726536, -72.8250564)
# 2      BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 3               NEW HAVEN, CT\n(41.3082517, -72.9241605)
# 4      NORWICH, CT\n(41.526760000000024, -72.07567999...
# ...                                                  ...
# 11976              STAMFORD, CT\n(41.051924, -73.539475)
# 11977            WEST HAVEN, CT\n(41.272336, -72.949817)
# 11978          WETHERSFIELD, CT\n(41.712487, -72.663607)
# 11979              HARTFORD, CT\n(41.765775, -72.673356)
# 11980               SEYMOUR, CT\n(41.395594, -73.073581)
#
#                                       DeathCityGeo
# 0                 CT\n(41.57350273, -72.738305908)
# 1                 CT\n(41.57350273, -72.738305908)
# 2      CT\n(41.57350273000003, -72.73830590799997)
# 3                 CT\n(41.57350273, -72.738305908)
# 4      CT\n(41.57350273000003, -72.73830590799997)
# ...                                            ...
# 11976        Stamford, CT\n(41.051924, -73.539475)
# 11977       New Haven, CT\n(41.308252, -72.924161)
# 11978        Hartford, CT\n(41.765775, -72.673356)
# 11979        Hartford, CT\n(41.765775, -72.673356)
# 11980         Seymour, CT\n(41.395594, -73.073581)
#
# [11981 rows x 48 columns]

# %%
import pandas as pd

def find_date_column(df):
    possible_date_cols = []

    for col in df.columns:
        try:
            parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
            valid_dates = parsed.notna().sum() / len(df)  # Percentage of valid entries

            # Ensure column was originally non-numeric before conversion
            is_object_or_string = df[col].dtype == "object" or pd.api.types.is_string_dtype(df[col])

            print(f"🔎 Checking '{col}': {valid_dates:.2%} valid dates | Type: {df[col].dtype}")  # Debugging

            if valid_dates > 0.6 and is_object_or_string:  # At least 60% valid dates & originally text-based
                possible_date_cols.append(col)
        except Exception as e:
            print(f"⚠️ Error processing '{col}': {e}")

    return possible_date_cols[0] if possible_date_cols else None

# Example usage:
date_col = find_date_column(df)
print(f"📅 Detected date column: {date_col}" if date_col else "❌ No date column detected!")
# Out:
# 🔎 Checking 'Date': 100.00% valid dates | Type: object
# 🔎 Checking 'Date Type': 0.00% valid dates | Type: object
# 🔎 Checking 'Age': 99.98% valid dates | Type: float64
# 🔎 Checking 'Sex': 0.00% valid dates | Type: object
# 🔎 Checking 'Race': 0.00% valid dates | Type: object
# 🔎 Checking 'Ethnicity': 0.00% valid dates | Type: object
# 🔎 Checking 'Residence City': 0.00% valid dates | Type: object
# 🔎 Checking 'Residence County': 0.00% valid dates | Type: object
# 🔎 Checking 'Residence State': 0.00% valid dates | Type: object
# 🔎 Checking 'Injury City': 0.00% valid dates | Type: object
# 🔎 Checking 'Injury County': 0.00% valid dates | Type: object
# 🔎 Checking 'Injury State': 0.00% valid dates | Type: object
# 🔎 Checking 'Injury Place': 0.00% valid dates | Type: object
# 🔎 Checking 'Description of Injury': 0.00% valid dates | Type: object
# 🔎 Checking 'Death City': 0.00% valid dates | Type: object
# 🔎 Checking 'Death County': 0.00% valid dates | Type: object
# 🔎 Checking 'Death State': 0.00% valid dates | Type: object
# 🔎 Checking 'Location': 0.00% valid dates | Type: object
# 🔎 Checking 'Location if Other': 0.00% valid dates | Type: object
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# 🔎 Checking 'Cause of Death': 0.00% valid dates | Type: object
# 🔎 Checking 'Manner of Death': 0.00% valid dates | Type: object
# 🔎 Checking 'Other Significant Conditions ': 0.00% valid dates | Type: object
# 🔎 Checking 'Heroin': 0.00% valid dates | Type: object
# 🔎 Checking 'Heroin death certificate (DC)': 0.00% valid dates | Type: object
# 🔎 Checking 'Cocaine': 0.00% valid dates | Type: object
# 🔎 Checking 'Fentanyl': 0.00% valid dates | Type: object
# 🔎 Checking 'Fentanyl Analogue': 0.00% valid dates | Type: object
# 🔎 Checking 'Oxycodone': 0.00% valid dates | Type: object
# 🔎 Checking 'Oxymorphone': 0.00% valid dates | Type: object
# 🔎 Checking 'Ethanol': 0.00% valid dates | Type: object
# 🔎 Checking 'Hydrocodone': 0.00% valid dates | Type: object
# 🔎 Checking 'Benzodiazepine': 0.00% valid dates | Type: object
# 🔎 Checking 'Methadone': 0.00% valid dates | Type: object
# 🔎 Checking 'Meth/Amphetamine': 0.00% valid dates | Type: object
# 🔎 Checking 'Amphet': 0.00% valid dates | Type: object
# 🔎 Checking 'Tramad': 0.00% valid dates | Type: object
# 🔎 Checking 'Hydromorphone': 0.00% valid dates | Type: object
# 🔎 Checking 'Morphine (Not Heroin)': 0.00% valid dates | Type: object
# 🔎 Checking 'Xylazine': 0.00% valid dates | Type: object
# 🔎 Checking 'Gabapentin': 0.00% valid dates | Type: object
# 🔎 Checking 'Opiate NOS': 0.00% valid dates | Type: object
# 🔎 Checking 'Heroin/Morph/Codeine': 0.00% valid dates | Type: object
# 🔎 Checking 'Other Opioid': 0.00% valid dates | Type: object
# 🔎 Checking 'Any Opioid': 0.00% valid dates | Type: object
# 🔎 Checking 'Other': 0.00% valid dates | Type: object
# 🔎 Checking 'ResidenceCityGeo': 0.00% valid dates | Type: object
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime
# 🔎 Checking 'InjuryCityGeo': 0.00% valid dates | Type: object
# 🔎 Checking 'DeathCityGeo': 0.00% valid dates | Type: object
# 📅 Detected date column: Date
# <ipython-input-2-3344209>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')  # Convert to datetime

# %%
df.loc[df.index[-50:], date_col] = pd.to_datetime(df[date_col], errors='coerce').dt.strftime('%B %d, %Y')

print(df)

count_written = df[date_col].astype(str).str.match(r'^[A-Za-z]+ \d{1,2}, \d{4}$').sum()
print(f"{count_written} dates are in written format! This data is inconsistent. Consider makeing entire {date_col} column the same format.")
# Out:
#                     Date      Date Type   Age   Sex  \
# 0             01/02/2023  Date of death  65.0  Male
# 1             01/18/2023  Date of death  42.0  Male
# 2             01/26/2022  Date of death  34.0  Male
# 3             02/04/2023  Date of death  34.0  Male
# 4             02/18/2022  Date of death  43.0  Male
# ...                  ...            ...   ...   ...
# 11976   October 19, 2021  Date of death  56.0  Male
# 11977       May 04, 2021  Date of death  48.0  Male
# 11978       May 15, 2021  Date of death  59.0  Male
# 11979       May 28, 2021  Date of death  68.0  Male
# 11980  December 24, 2021  Date of death  29.0  Male
#
#                             Race                        Ethnicity  \
# 0                          White  No, not Spanish/Hispanic/Latino
# 1                          White  No, not Spanish/Hispanic/Latino
# 2                          White                              NaN
# 3                          White                              NaN
# 4                          White                              NaN
# ...                          ...                              ...
# 11976  Black or African American                              NaN
# 11977  Black or African American                              NaN
# 11978                      White                              NaN
# 11979  Black or African American                              NaN
# 11980                      White      Not Spanish/Hispanic/Latino
#
#       Residence City Residence County Residence State   Injury City  ...  \
# 0         BRIDGEPORT        FAIRFIELD              CT    BRIDGEPORT  ...
# 1          WATERBURY        NEW HAVEN              CT    FARMINGTON  ...
# 2         BROOKFIELD        FAIRFIELD              CT    BROOKFIELD  ...
# 3                NaN              NaN             NaN     NEW HAVEN  ...
# 4            NORWICH       NEW LONDON              CT       NORWICH  ...
# ...              ...              ...             ...           ...  ...
# 11976       STAMFORD        FAIRFIELD              CT      STAMFORD  ...
# 11977     WEST HAVEN        NEW HAVEN              CT    WEST HAVEN  ...
# 11978   WETHERSFIELD         HARTFORD              CT  WETHERSFIELD  ...
# 11979       HARTFORD         HARTFORD              CT      HARTFORD  ...
# 11980        SEYMOUR        NEW HAVEN              CT       SEYMOUR  ...
#
#       Xylazine Gabapentin Opiate NOS Heroin/Morph/Codeine Other Opioid  \
# 0          NaN        NaN        NaN                  NaN          NaN
# 1          NaN        NaN        NaN                  NaN          NaN
# 2            Y        NaN        NaN                    Y          NaN
# 3          NaN        NaN        NaN                  NaN          NaN
# 4          NaN        NaN        NaN                  NaN          NaN
# ...        ...        ...        ...                  ...          ...
# 11976      NaN        NaN        NaN                  NaN          NaN
# 11977      NaN        NaN        NaN                  NaN          NaN
# 11978      NaN          Y        NaN                  NaN          NaN
# 11979      NaN        NaN        NaN                  NaN          NaN
# 11980        Y        NaN        NaN                  NaN          NaN
#
#       Any Opioid Other                                   ResidenceCityGeo  \
# 0              Y   NaN            BRIDGEPORT, CT\n(41.179195, -73.189476)
# 1              Y   NaN           WATERBURY, CT\n(41.5542609, -73.0430692)
# 2              Y   NaN  BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 3              Y   NaN                   CT\n(41.57350273, -72.738305908)
# 4              Y   NaN  NORWICH, CT\n(41.526760000000024, -72.07567999...
# ...          ...   ...                                                ...
# 11976          Y   PCP              STAMFORD, CT\n(41.051924, -73.539475)
# 11977        NaN   NaN            WEST HAVEN, CT\n(41.272336, -72.949817)
# 11978        NaN   NaN          WETHERSFIELD, CT\n(41.712487, -72.663607)
# 11979        NaN   NaN              HARTFORD, CT\n(41.765775, -72.673356)
# 11980          Y   NaN               SEYMOUR, CT\n(41.395594, -73.073581)
#
#                                            InjuryCityGeo  \
# 0                BRIDGEPORT, CT\n(41.179195, -73.189476)
# 1               FARMINGTON, CT\n(41.726536, -72.8250564)
# 2      BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 3               NEW HAVEN, CT\n(41.3082517, -72.9241605)
# 4      NORWICH, CT\n(41.526760000000024, -72.07567999...
# ...                                                  ...
# 11976              STAMFORD, CT\n(41.051924, -73.539475)
# 11977            WEST HAVEN, CT\n(41.272336, -72.949817)
# 11978          WETHERSFIELD, CT\n(41.712487, -72.663607)
# 11979              HARTFORD, CT\n(41.765775, -72.673356)
# 11980               SEYMOUR, CT\n(41.395594, -73.073581)
#
#                                       DeathCityGeo
# 0                 CT\n(41.57350273, -72.738305908)
# 1                 CT\n(41.57350273, -72.738305908)
# 2      CT\n(41.57350273000003, -72.73830590799997)
# 3                 CT\n(41.57350273, -72.738305908)
# 4      CT\n(41.57350273000003, -72.73830590799997)
# ...                                            ...
# 11976        Stamford, CT\n(41.051924, -73.539475)
# 11977       New Haven, CT\n(41.308252, -72.924161)
# 11978        Hartford, CT\n(41.765775, -72.673356)
# 11979        Hartford, CT\n(41.765775, -72.673356)
# 11980         Seymour, CT\n(41.395594, -73.073581)
#
# [11981 rows x 48 columns]
# 50 dates are in written format! This data is inconsistent. Consider makeing entire Date column the same format.

# %%
def format_date_columns(df, date_cols, format_string):
    # Ensure date_cols is a list even if a single column name is passed as a string
    if isinstance(date_cols, str):
        date_cols = [date_cols]

    for col in date_cols:
      # Use errors='coerce' in to_datetime to handle potential parsing issues
      df[col] = pd.to_datetime(df[col], errors='coerce', format='mixed').dt.strftime(format_string)
    return df

format_string = '%Y-%m-%d' # Desired output format

# Pass date_col as a list containing the column name
df = format_date_columns(df, date_col, format_string)
print(df)

count_written = df[date_col].astype(str).str.match(r'^[A-Za-z]+ \d{1,2}, \d{4}$').sum()

print(f"{count_written} dates are in written format! {date_col} column is now in the same format. This data is now consistent.")
# Out:
#              Date      Date Type   Age   Sex                       Race  \
# 0      2023-01-02  Date of death  65.0  Male                      White
# 1      2023-01-18  Date of death  42.0  Male                      White
# 2      2022-01-26  Date of death  34.0  Male                      White
# 3      2023-02-04  Date of death  34.0  Male                      White
# 4      2022-02-18  Date of death  43.0  Male                      White
# ...           ...            ...   ...   ...                        ...
# 11976  2021-10-19  Date of death  56.0  Male  Black or African American
# 11977  2021-05-04  Date of death  48.0  Male  Black or African American
# 11978  2021-05-15  Date of death  59.0  Male                      White
# 11979  2021-05-28  Date of death  68.0  Male  Black or African American
# 11980  2021-12-24  Date of death  29.0  Male                      White
#
#                              Ethnicity Residence City Residence County  \
# 0      No, not Spanish/Hispanic/Latino     BRIDGEPORT        FAIRFIELD
# 1      No, not Spanish/Hispanic/Latino      WATERBURY        NEW HAVEN
# 2                                  NaN     BROOKFIELD        FAIRFIELD
# 3                                  NaN            NaN              NaN
# 4                                  NaN        NORWICH       NEW LONDON
# ...                                ...            ...              ...
# 11976                              NaN       STAMFORD        FAIRFIELD
# 11977                              NaN     WEST HAVEN        NEW HAVEN
# 11978                              NaN   WETHERSFIELD         HARTFORD
# 11979                              NaN       HARTFORD         HARTFORD
# 11980      Not Spanish/Hispanic/Latino        SEYMOUR        NEW HAVEN
#
#       Residence State   Injury City  ... Xylazine Gabapentin Opiate NOS  \
# 0                  CT    BRIDGEPORT  ...      NaN        NaN        NaN
# 1                  CT    FARMINGTON  ...      NaN        NaN        NaN
# 2                  CT    BROOKFIELD  ...        Y        NaN        NaN
# 3                 NaN     NEW HAVEN  ...      NaN        NaN        NaN
# 4                  CT       NORWICH  ...      NaN        NaN        NaN
# ...               ...           ...  ...      ...        ...        ...
# 11976              CT      STAMFORD  ...      NaN        NaN        NaN
# 11977              CT    WEST HAVEN  ...      NaN        NaN        NaN
# 11978              CT  WETHERSFIELD  ...      NaN          Y        NaN
# 11979              CT      HARTFORD  ...      NaN        NaN        NaN
# 11980              CT       SEYMOUR  ...        Y        NaN        NaN
#
#       Heroin/Morph/Codeine Other Opioid Any Opioid Other  \
# 0                      NaN          NaN          Y   NaN
# 1                      NaN          NaN          Y   NaN
# 2                        Y          NaN          Y   NaN
# 3                      NaN          NaN          Y   NaN
# 4                      NaN          NaN          Y   NaN
# ...                    ...          ...        ...   ...
# 11976                  NaN          NaN          Y   PCP
# 11977                  NaN          NaN        NaN   NaN
# 11978                  NaN          NaN        NaN   NaN
# 11979                  NaN          NaN        NaN   NaN
# 11980                  NaN          NaN          Y   NaN
#
#                                         ResidenceCityGeo  \
# 0                BRIDGEPORT, CT\n(41.179195, -73.189476)
# 1               WATERBURY, CT\n(41.5542609, -73.0430692)
# 2      BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 3                       CT\n(41.57350273, -72.738305908)
# 4      NORWICH, CT\n(41.526760000000024, -72.07567999...
# ...                                                  ...
# 11976              STAMFORD, CT\n(41.051924, -73.539475)
# 11977            WEST HAVEN, CT\n(41.272336, -72.949817)
# 11978          WETHERSFIELD, CT\n(41.712487, -72.663607)
# 11979              HARTFORD, CT\n(41.765775, -72.673356)
# 11980               SEYMOUR, CT\n(41.395594, -73.073581)
#
#                                            InjuryCityGeo  \
# 0                BRIDGEPORT, CT\n(41.179195, -73.189476)
# 1               FARMINGTON, CT\n(41.726536, -72.8250564)
# 2      BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 3               NEW HAVEN, CT\n(41.3082517, -72.9241605)
# 4      NORWICH, CT\n(41.526760000000024, -72.07567999...
# ...                                                  ...
# 11976              STAMFORD, CT\n(41.051924, -73.539475)
# 11977            WEST HAVEN, CT\n(41.272336, -72.949817)
# 11978          WETHERSFIELD, CT\n(41.712487, -72.663607)
# 11979              HARTFORD, CT\n(41.765775, -72.673356)
# 11980               SEYMOUR, CT\n(41.395594, -73.073581)
#
#                                       DeathCityGeo
# 0                 CT\n(41.57350273, -72.738305908)
# 1                 CT\n(41.57350273, -72.738305908)
# 2      CT\n(41.57350273000003, -72.73830590799997)
# 3                 CT\n(41.57350273, -72.738305908)
# 4      CT\n(41.57350273000003, -72.73830590799997)
# ...                                            ...
# 11976        Stamford, CT\n(41.051924, -73.539475)
# 11977       New Haven, CT\n(41.308252, -72.924161)
# 11978        Hartford, CT\n(41.765775, -72.673356)
# 11979        Hartford, CT\n(41.765775, -72.673356)
# 11980         Seymour, CT\n(41.395594, -73.073581)
#
# [11981 rows x 48 columns]
# 0 dates are in written format! Date column is now in the same format. This data is now consistent.

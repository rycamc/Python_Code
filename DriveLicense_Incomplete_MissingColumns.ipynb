# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/DataSet-01-All_Licenses.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-5-ce9a0bcbac87>:11: DtypeWarning: Columns (5,11,13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
#                 License Type         First Name  Last Name Suffix  \
# 0       Institutional Permit            JULIO M    SCHWARZ    NaN
# 1       Institutional Permit       SYED MANSOOR      AHMED    NaN
# 2       Institutional Permit       KENNETH MARK     ELLNER    NaN
# 3       Institutional Permit  ELIZABETH YARDLEY     BOEHME    NaN
# 4       Institutional Permit    LAWRENCE EDWARD     GERING    NaN
# ...                      ...                ...        ...    ...
# 486555     Physician License             MARYAM      ZAFER    NaN
# 486556     Physician License                HUI      ZHANG    NaN
# 486557     Physician License           CAROLINE        ZHU    NaN
# 486558     Physician License        ERIC ROBERT  ZIELINSKI    NaN
# 486559     Physician License     ROLAND CHARLES     KUPPER    NaN
#
#         Year of Birth License Number      License Issue Date  \
# 0              1951.0          10000  07/01/1986 12:00:00 AM
# 1              1955.0          10001  08/14/1989 12:00:00 AM
# 2              1959.0          10003  07/01/1986 12:00:00 AM
# 3              1958.0          10004  07/01/1986 12:00:00 AM
# 4              1959.0          10005  07/01/1986 12:00:00 AM
# ...               ...            ...                     ...
# 486555         1990.0          V9180  05/30/2025 12:00:00 AM
# 486556         1969.0          V9181  05/30/2025 12:00:00 AM
# 486557         1996.0          V9182  05/30/2025 12:00:00 AM
# 486558         1988.0          V9183  05/30/2025 12:00:00 AM
# 486559         1904.0          Z4634  07/31/1937 12:00:00 AM
#
#        License Expiration Date Registration Status Registration Status Date  \
# 0       06/30/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 1       08/13/1990 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 2       07/01/1987 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 3       06/30/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 4       07/01/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# ...                        ...                 ...                      ...
# 486555  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486556  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486557  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486558  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486559  05/31/1988 12:00:00 AM            DECEASED   07/07/1989 12:00:00 AM
#
#         ... License Status Date Degree Specialties  \
# 0       ...                 NaN      P         NaN
# 1       ...                 NaN      P         NaN
# 2       ...                 NaN      P         NaN
# 3       ...                 NaN      P         NaN
# 4       ...                 NaN      P         NaN
# ...     ...                 ...    ...         ...
# 486555  ...                 NaN     MD         NaN
# 486556  ...                 NaN     MD         NaN
# 486557  ...                 NaN     MD         NaN
# 486558  ...                 NaN     MD         NaN
# 486559  ...                 NaN     MD         NaN
#
#                                          Practice Address Practice City  \
# 0                                                     NaN           NaN
# 1                                     1155 N MAYFAIR ROAD     MILWAUKEE
# 2       ATLANTA CENTER FOR DERMATOLOGI 1265 UPPER HEMB...       ROSWELL
# 3                                  3400 BISSONNET,STE 100       HOUSTON
# 4             6535 FANNIN / MS-F905 SECTION OF CARDIOLOGY       HOUSTON
# ...                                                   ...           ...
# 486555                                                NaN           NaN
# 486556                                                NaN           NaN
# 486557                                                NaN           NaN
# 486558                                                NaN           NaN
# 486559                                    NOT IN PRACTICE   SAN ANTONIO
#
#        Practice State Practice Zip Currently Licensed  \
# 0                 NaN          NaN                  N
# 1                  WI        53226                  N
# 2                  GA        30075                  N
# 3                  TX        77005                  N
# 4                  TX        77030                  N
# ...               ...          ...                ...
# 486555            NaN          NaN                  Y
# 486556            NaN          NaN                  Y
# 486557            NaN          NaN                  Y
# 486558            NaN          NaN                  Y
# 486559             TX        78217                  N
#
#        Current Board Action Date Current Board Action Description
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ...                          ...                              ...
# 486555                       NaN                              NaN
# 486556                       NaN                              NaN
# 486557                       NaN                              NaN
# 486558                       NaN                              NaN
# 486559                       NaN                              NaN
#
# [486560 rows x 23 columns]

# %%
import pandas as pd

df_remove = df

def readd_first_three_cols(df_remove):
    # Store the first 3 columns
    first_three_cols = df_remove.iloc[:, :3]

    # Delete the first 3 columns
    df_remove = df_remove.iloc[:, 3:]

    return df_remove

print("Original DataFrame:")
print(df)

df_remove = readd_first_three_cols(df_remove)
print("\nDataFrame with first 3 columns deleted:")
print(df_remove)
# Out:
# Original DataFrame:
#                 License Type         First Name  Last Name Suffix  \
# 0       Institutional Permit            JULIO M    SCHWARZ    NaN
# 1       Institutional Permit       SYED MANSOOR      AHMED    NaN
# 2       Institutional Permit       KENNETH MARK     ELLNER    NaN
# 3       Institutional Permit  ELIZABETH YARDLEY     BOEHME    NaN
# 4       Institutional Permit    LAWRENCE EDWARD     GERING    NaN
# ...                      ...                ...        ...    ...
# 486555     Physician License             MARYAM      ZAFER    NaN
# 486556     Physician License                HUI      ZHANG    NaN
# 486557     Physician License           CAROLINE        ZHU    NaN
# 486558     Physician License        ERIC ROBERT  ZIELINSKI    NaN
# 486559     Physician License     ROLAND CHARLES     KUPPER    NaN
#
#         Year of Birth License Number      License Issue Date  \
# 0              1951.0          10000  07/01/1986 12:00:00 AM
# 1              1955.0          10001  08/14/1989 12:00:00 AM
# 2              1959.0          10003  07/01/1986 12:00:00 AM
# 3              1958.0          10004  07/01/1986 12:00:00 AM
# 4              1959.0          10005  07/01/1986 12:00:00 AM
# ...               ...            ...                     ...
# 486555         1990.0          V9180  05/30/2025 12:00:00 AM
# 486556         1969.0          V9181  05/30/2025 12:00:00 AM
# 486557         1996.0          V9182  05/30/2025 12:00:00 AM
# 486558         1988.0          V9183  05/30/2025 12:00:00 AM
# 486559         1904.0          Z4634  07/31/1937 12:00:00 AM
#
#        License Expiration Date Registration Status Registration Status Date  \
# 0       06/30/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 1       08/13/1990 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 2       07/01/1987 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 3       06/30/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 4       07/01/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# ...                        ...                 ...                      ...
# 486555  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486556  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486557  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486558  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486559  05/31/1988 12:00:00 AM            DECEASED   07/07/1989 12:00:00 AM
#
#         ... License Status Date Degree Specialties  \
# 0       ...                 NaN      P         NaN
# 1       ...                 NaN      P         NaN
# 2       ...                 NaN      P         NaN
# 3       ...                 NaN      P         NaN
# 4       ...                 NaN      P         NaN
# ...     ...                 ...    ...         ...
# 486555  ...                 NaN     MD         NaN
# 486556  ...                 NaN     MD         NaN
# 486557  ...                 NaN     MD         NaN
# 486558  ...                 NaN     MD         NaN
# 486559  ...                 NaN     MD         NaN
#
#                                          Practice Address Practice City  \
# 0                                                     NaN           NaN
# 1                                     1155 N MAYFAIR ROAD     MILWAUKEE
# 2       ATLANTA CENTER FOR DERMATOLOGI 1265 UPPER HEMB...       ROSWELL
# 3                                  3400 BISSONNET,STE 100       HOUSTON
# 4             6535 FANNIN / MS-F905 SECTION OF CARDIOLOGY       HOUSTON
# ...                                                   ...           ...
# 486555                                                NaN           NaN
# 486556                                                NaN           NaN
# 486557                                                NaN           NaN
# 486558                                                NaN           NaN
# 486559                                    NOT IN PRACTICE   SAN ANTONIO
#
#        Practice State Practice Zip Currently Licensed  \
# 0                 NaN          NaN                  N
# 1                  WI        53226                  N
# 2                  GA        30075                  N
# 3                  TX        77005                  N
# 4                  TX        77030                  N
# ...               ...          ...                ...
# 486555            NaN          NaN                  Y
# 486556            NaN          NaN                  Y
# 486557            NaN          NaN                  Y
# 486558            NaN          NaN                  Y
# 486559             TX        78217                  N
#
#        Current Board Action Date Current Board Action Description
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ...                          ...                              ...
# 486555                       NaN                              NaN
# 486556                       NaN                              NaN
# 486557                       NaN                              NaN
# 486558                       NaN                              NaN
# 486559                       NaN                              NaN
#
# [486560 rows x 23 columns]
#
# DataFrame with first 3 columns deleted:
#        Suffix  Year of Birth License Number      License Issue Date  \
# 0         NaN         1951.0          10000  07/01/1986 12:00:00 AM
# 1         NaN         1955.0          10001  08/14/1989 12:00:00 AM
# 2         NaN         1959.0          10003  07/01/1986 12:00:00 AM
# 3         NaN         1958.0          10004  07/01/1986 12:00:00 AM
# 4         NaN         1959.0          10005  07/01/1986 12:00:00 AM
# ...       ...            ...            ...                     ...
# 486555    NaN         1990.0          V9180  05/30/2025 12:00:00 AM
# 486556    NaN         1969.0          V9181  05/30/2025 12:00:00 AM
# 486557    NaN         1996.0          V9182  05/30/2025 12:00:00 AM
# 486558    NaN         1988.0          V9183  05/30/2025 12:00:00 AM
# 486559    NaN         1904.0          Z4634  07/31/1937 12:00:00 AM
#
#        License Expiration Date Registration Status Registration Status Date  \
# 0       06/30/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 1       08/13/1990 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 2       07/01/1987 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 3       06/30/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# 4       07/01/1988 12:00:00 AM          Terminated   02/21/2007 12:00:00 AM
# ...                        ...                 ...                      ...
# 486555  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486556  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486557  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486558  08/28/2025 12:00:00 AM      LICENSE ISSUED   05/30/2025 12:00:00 AM
# 486559  05/31/1988 12:00:00 AM            DECEASED   07/07/1989 12:00:00 AM
#
#        Disciplinary Status Disciplinary Status Date License Status  \
# 0                     NONE                      NaN           NONE
# 1                     NONE                      NaN           NONE
# 2                     NONE                      NaN           NONE
# 3                     NONE                      NaN           NONE
# 4                     NONE                      NaN           NONE
# ...                    ...                      ...            ...
# 486555                NONE                      NaN           NONE
# 486556                NONE                      NaN           NONE
# 486557                NONE                      NaN           NONE
# 486558                NONE                      NaN           NONE
# 486559                NONE                      NaN           NONE
#
#        License Status Date Degree Specialties  \
# 0                      NaN      P         NaN
# 1                      NaN      P         NaN
# 2                      NaN      P         NaN
# 3                      NaN      P         NaN
# 4                      NaN      P         NaN
# ...                    ...    ...         ...
# 486555                 NaN     MD         NaN
# 486556                 NaN     MD         NaN
# 486557                 NaN     MD         NaN
# 486558                 NaN     MD         NaN
# 486559                 NaN     MD         NaN
#
#                                          Practice Address Practice City  \
# 0                                                     NaN           NaN
# 1                                     1155 N MAYFAIR ROAD     MILWAUKEE
# 2       ATLANTA CENTER FOR DERMATOLOGI 1265 UPPER HEMB...       ROSWELL
# 3                                  3400 BISSONNET,STE 100       HOUSTON
# 4             6535 FANNIN / MS-F905 SECTION OF CARDIOLOGY       HOUSTON
# ...                                                   ...           ...
# 486555                                                NaN           NaN
# 486556                                                NaN           NaN
# 486557                                                NaN           NaN
# 486558                                                NaN           NaN
# 486559                                    NOT IN PRACTICE   SAN ANTONIO
#
#        Practice State Practice Zip Currently Licensed  \
# 0                 NaN          NaN                  N
# 1                  WI        53226                  N
# 2                  GA        30075                  N
# 3                  TX        77005                  N
# 4                  TX        77030                  N
# ...               ...          ...                ...
# 486555            NaN          NaN                  Y
# 486556            NaN          NaN                  Y
# 486557            NaN          NaN                  Y
# 486558            NaN          NaN                  Y
# 486559             TX        78217                  N
#
#        Current Board Action Date Current Board Action Description
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ...                          ...                              ...
# 486555                       NaN                              NaN
# 486556                       NaN                              NaN
# 486557                       NaN                              NaN
# 486558                       NaN                              NaN
# 486559                       NaN                              NaN
#
# [486560 rows x 20 columns]

# %%
def compare_columns(df, df_remove):
    """
    Compares the columns of two DataFrames and prints the differences.

    Args:
        df1: The first DataFrame.
        df2: The second DataFrame.
    """
    cols1 = set(df.columns)
    cols2 = set(df_remove.columns)

    added_cols = cols2 - cols1
    removed_cols = cols1 - cols2
    common_cols = cols1.intersection(cols2)

    print("Columns missing that are needed to answer query:", removed_cols)



compare_columns(df, df_remove)
# Out:
# Columns missing that are needed to answer query: {'License Type', 'Last Name', 'First Name'}

# %%
# List of required column names
required_columns =  df.iloc[:, :3]

# Check for missing columns and print a message
missing_columns = [col for col in required_columns if col not in df.columns]

if missing_columns:
    print(f"Error: The following required columns are missing from the DataFrame: {missing_columns}")
else:
    print("All required columns are now present in the DataFrame. The query can be answered.")
# Out:
# All required columns are now present in the DataFrame. The query can be answered.

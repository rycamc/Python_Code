# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/Paid_Parking__Last_48_Hours_.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#              OccupancyDateTime  PaidOccupancy  \
# 0       06/02/2025 02:54:00 PM             10
# 1       05/29/2025 10:48:00 AM              6
# 2       05/30/2025 01:59:00 PM              1
# 3       05/30/2025 01:07:00 PM              6
# 4       05/30/2025 01:35:00 PM              3
# ...                        ...            ...
# 195842  06/02/2025 01:51:00 PM              1
# 195843  06/02/2025 07:02:00 PM              1
# 195844  06/02/2025 01:48:00 PM              1
# 195845  05/29/2025 01:01:00 PM              1
# 195846  05/30/2025 04:45:00 PM              3
#
#                                             BlockfaceName SideOfStreet  \
# 0          NW 56TH ST BETWEEN 22ND AVE NW AND 24TH AVE NW            S
# 1       ROOSEVELT WAY NE BETWEEN NE 64TH ST AND NE 65T...            E
# 2          UNIVERSITY ST BETWEEN MINOR AVE AND SUMMIT AVE           NW
# 3             POST AVE BETWEEN YESLER WAY AND COLUMBIA ST           NE
# 4                5TH AVE BETWEEN MADISON ST AND SPRING ST           SW
# ...                                                   ...          ...
# 195842  NE 66TH ST BETWEEN ROOSEVELT WAY NE AND 12TH A...            N
# 195843  E REPUBLICAN ST BETWEEN BROADWAY E AND 10TH AVE E            S
# 195844          SENECA ST BETWEEN TERRY AVE AND BOREN AVE           SE
# 195845          7TH AVE BETWEEN CHERRY ST AND COLUMBIA ST           NE
# 195846       S KING ST BETWEEN MAYNARD AL S AND 7TH AVE S            N
#
#         SourceElementKey  ParkingTimeLimitCategory  ParkingSpaceCount  \
# 0                  86450                       240                 14
# 1                  57914                       240                  8
# 2                  81205                       120                  8
# 3                  12238                       120                  8
# 4                  75153                       120                  5
# ...                  ...                       ...                ...
# 195842             39877                       240                  9
# 195843             14770                       120                  6
# 195844             80742                       120                  9
# 195845              8242                       120                  5
# 195846            123744                       120                  4
#
#         PaidParkingArea PaidParkingSubArea  PaidParkingRate ParkingCategory  \
# 0               Ballard               Edge              NaN    Paid Parking
# 1             Roosevelt                NaN              NaN    Paid Parking
# 2            First Hill                NaN              NaN    Paid Parking
# 3        Pioneer Square               Edge              NaN    Paid Parking
# 4       Commercial Core          Financial              NaN    Paid Parking
# ...                 ...                ...              ...             ...
# 195842        Roosevelt                NaN              NaN    Paid Parking
# 195843     Capitol Hill              North              NaN    Paid Parking
# 195844       First Hill                NaN              NaN    Paid Parking
# 195845       First Hill                NaN              NaN    Paid Parking
# 195846     Chinatown/ID                NaN              NaN    Paid Parking
#
#                                  Location
# 0       POINT (-122.38619958 47.66938747)
# 1       POINT (-122.31727794 47.67538932)
# 2       POINT (-122.32548222 47.61222854)
# 3       POINT (-122.33493291 47.60244125)
# 4       POINT (-122.33220159 47.60687895)
# ...                                   ...
# 195842   POINT (-122.31678499 47.6765921)
# 195843  POINT (-122.32036529 47.62308318)
# 195844   POINT (-122.3269907 47.61045314)
# 195845  POINT (-122.32786582 47.60573702)
# 195846                                 PO
#
# [195847 rows x 12 columns]

# %%
import pandas as pd

df_remove = df

def readd_first_three_cols(df_remove):
    # Store the first 3 columns
    first_three_cols = df_remove.iloc[:, :3]

    # Delete the first 3 columns
    df_remove = df_remove.iloc[:, 3:]

    return df_remove

print("Original DataFrame:")
print(df)

df_remove = readd_first_three_cols(df_remove)
print("\nDataFrame with first 3 columns deleted:")
print(df_remove)
# Out:
# Original DataFrame:
#              OccupancyDateTime  PaidOccupancy  \
# 0       06/02/2025 02:54:00 PM             10
# 1       05/29/2025 10:48:00 AM              6
# 2       05/30/2025 01:59:00 PM              1
# 3       05/30/2025 01:07:00 PM              6
# 4       05/30/2025 01:35:00 PM              3
# ...                        ...            ...
# 195842  06/02/2025 01:51:00 PM              1
# 195843  06/02/2025 07:02:00 PM              1
# 195844  06/02/2025 01:48:00 PM              1
# 195845  05/29/2025 01:01:00 PM              1
# 195846  05/30/2025 04:45:00 PM              3
#
#                                             BlockfaceName SideOfStreet  \
# 0          NW 56TH ST BETWEEN 22ND AVE NW AND 24TH AVE NW            S
# 1       ROOSEVELT WAY NE BETWEEN NE 64TH ST AND NE 65T...            E
# 2          UNIVERSITY ST BETWEEN MINOR AVE AND SUMMIT AVE           NW
# 3             POST AVE BETWEEN YESLER WAY AND COLUMBIA ST           NE
# 4                5TH AVE BETWEEN MADISON ST AND SPRING ST           SW
# ...                                                   ...          ...
# 195842  NE 66TH ST BETWEEN ROOSEVELT WAY NE AND 12TH A...            N
# 195843  E REPUBLICAN ST BETWEEN BROADWAY E AND 10TH AVE E            S
# 195844          SENECA ST BETWEEN TERRY AVE AND BOREN AVE           SE
# 195845          7TH AVE BETWEEN CHERRY ST AND COLUMBIA ST           NE
# 195846       S KING ST BETWEEN MAYNARD AL S AND 7TH AVE S            N
#
#         SourceElementKey  ParkingTimeLimitCategory  ParkingSpaceCount  \
# 0                  86450                       240                 14
# 1                  57914                       240                  8
# 2                  81205                       120                  8
# 3                  12238                       120                  8
# 4                  75153                       120                  5
# ...                  ...                       ...                ...
# 195842             39877                       240                  9
# 195843             14770                       120                  6
# 195844             80742                       120                  9
# 195845              8242                       120                  5
# 195846            123744                       120                  4
#
#         PaidParkingArea PaidParkingSubArea  PaidParkingRate ParkingCategory  \
# 0               Ballard               Edge              NaN    Paid Parking
# 1             Roosevelt                NaN              NaN    Paid Parking
# 2            First Hill                NaN              NaN    Paid Parking
# 3        Pioneer Square               Edge              NaN    Paid Parking
# 4       Commercial Core          Financial              NaN    Paid Parking
# ...                 ...                ...              ...             ...
# 195842        Roosevelt                NaN              NaN    Paid Parking
# 195843     Capitol Hill              North              NaN    Paid Parking
# 195844       First Hill                NaN              NaN    Paid Parking
# 195845       First Hill                NaN              NaN    Paid Parking
# 195846     Chinatown/ID                NaN              NaN    Paid Parking
#
#                                  Location
# 0       POINT (-122.38619958 47.66938747)
# 1       POINT (-122.31727794 47.67538932)
# 2       POINT (-122.32548222 47.61222854)
# 3       POINT (-122.33493291 47.60244125)
# 4       POINT (-122.33220159 47.60687895)
# ...                                   ...
# 195842   POINT (-122.31678499 47.6765921)
# 195843  POINT (-122.32036529 47.62308318)
# 195844   POINT (-122.3269907 47.61045314)
# 195845  POINT (-122.32786582 47.60573702)
# 195846                                 PO
#
# [195847 rows x 12 columns]
#
# DataFrame with first 3 columns deleted:
#        SideOfStreet  SourceElementKey  ParkingTimeLimitCategory  \
# 0                 S             86450                       240
# 1                 E             57914                       240
# 2                NW             81205                       120
# 3                NE             12238                       120
# 4                SW             75153                       120
# ...             ...               ...                       ...
# 195842            N             39877                       240
# 195843            S             14770                       120
# 195844           SE             80742                       120
# 195845           NE              8242                       120
# 195846            N            123744                       120
#
#         ParkingSpaceCount  PaidParkingArea PaidParkingSubArea  \
# 0                      14          Ballard               Edge
# 1                       8        Roosevelt                NaN
# 2                       8       First Hill                NaN
# 3                       8   Pioneer Square               Edge
# 4                       5  Commercial Core          Financial
# ...                   ...              ...                ...
# 195842                  9        Roosevelt                NaN
# 195843                  6     Capitol Hill              North
# 195844                  9       First Hill                NaN
# 195845                  5       First Hill                NaN
# 195846                  4     Chinatown/ID                NaN
#
#         PaidParkingRate ParkingCategory                           Location
# 0                   NaN    Paid Parking  POINT (-122.38619958 47.66938747)
# 1                   NaN    Paid Parking  POINT (-122.31727794 47.67538932)
# 2                   NaN    Paid Parking  POINT (-122.32548222 47.61222854)
# 3                   NaN    Paid Parking  POINT (-122.33493291 47.60244125)
# 4                   NaN    Paid Parking  POINT (-122.33220159 47.60687895)
# ...                 ...             ...                                ...
# 195842              NaN    Paid Parking   POINT (-122.31678499 47.6765921)
# 195843              NaN    Paid Parking  POINT (-122.32036529 47.62308318)
# 195844              NaN    Paid Parking   POINT (-122.3269907 47.61045314)
# 195845              NaN    Paid Parking  POINT (-122.32786582 47.60573702)
# 195846              NaN    Paid Parking                                 PO
#
# [195847 rows x 9 columns]

# %%
def compare_columns(df, df_remove):
    """
    Compares the columns of two DataFrames and prints the differences.

    Args:
        df1: The first DataFrame.
        df2: The second DataFrame.
    """
    cols1 = set(df.columns)
    cols2 = set(df_remove.columns)

    added_cols = cols2 - cols1
    removed_cols = cols1 - cols2
    common_cols = cols1.intersection(cols2)

    print("Columns missing that are needed to answer query:", removed_cols)



compare_columns(df, df_remove)
# Out:
# Columns missing that are needed to answer query: {'BlockfaceName', 'PaidOccupancy', 'OccupancyDateTime'}

# %%
# List of required column names
required_columns =  df.iloc[:, :3]

# Check for missing columns and print a message
missing_columns = [col for col in required_columns if col not in df.columns]

if missing_columns:
    print(f"Error: The following required columns are missing from the DataFrame: {missing_columns}")
else:
    print("All required columns are now present in the DataFrame. The query can be answered.")
# Out:
# All required columns are now present in the DataFrame. The query can be answered.

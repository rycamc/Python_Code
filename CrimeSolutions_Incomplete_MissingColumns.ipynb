# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/CrimeSolutions.gov_Programs.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Mounted at /content/drive
#      InterventionPublic_ID  Intervention_ID  \
# 0                     7531               39
# 1                     7558               40
# 2                     6028               41
# 3                     7105               42
# 4                     7110               43
# ..                     ...              ...
# 695                   7792             1795
# 696                   7787             1796
# 697                   7795             1797
# 698                   7794             1798
# 699                   7798             1799
#
#                                                  Title  \
# 0    Program Profile: San Francisco (Calif.) Behavi...
# 1                        Program Profile: Forever Free
# 2    Program Profile: Strong African American Famil...
# 3    Program Profile: Boston (Massachusetts) Reentr...
# 4    Program Profile: Child and Family Traumatic St...
# ..                                                 ...
# 695  Program Profile: Restorative Justice Conferenc...
# 696  Program Profile: Geographically Based Focused ...
# 697  Program Profile: North Dakota’s 24/7 Sobriety ...
# 698  Program Profile: Supervision with Immediate En...
# 699  Program Profile: Take CHARGE! Curriculum for S...
#
#                      Evidence Rating  \
# 0              Promising - One study
# 1              Promising - One study
# 2    Effective - More than one study
# 3              Promising - One study
# 4              Promising - One study
# ..                               ...
# 695           No Effects - One study
# 696            Promising - One study
# 697            Promising - One study
# 698            Promising - One study
# 699            Effective - One study
#
#                                                 Topics  \
# 0                     Courts, Crime & Crime Prevention
# 1    Corrections & Reentry, Crime & Crime Preventio...
# 2                   Drugs & Substance Abuse, Juveniles
# 3                                Corrections & Reentry
# 4                   Juveniles, Victims & Victimization
# ..                                                 ...
# 695                 Juveniles, Victims & Victimization
# 696  Crime & Crime Prevention, Law Enforcement, Vic...
# 697  Corrections & Reentry, Courts, Crime & Crime P...
# 698  Corrections & Reentry, Courts, Crime & Crime P...
# 699                                          Juveniles
#
#                                                Summary  \
# 0    The court aims to connect defendants with seri...
# 1    This prison-based substance abuse treatment pr...
# 2    This is a parental training and family therapy...
# 3    This interagency public safety initiative aims...
# 4    This is a brief early intervention and seconda...
# ..                                                 ...
# 695  This is a school program to address student mi...
# 696  This was a focused deterrence intervention des...
# 697  This program seeks to reduce the rearrests of ...
# 698  This is a specialized court program that targe...
# 699  This is a curriculum that targets students wit...
#
#      Randomized Controlled Trial  \
# 0                            NaN
# 1                            NaN
# 2    Randomized Controlled Trial
# 3                            NaN
# 4    Randomized Controlled Trial
# ..                           ...
# 695                          NaN
# 696                          NaN
# 697                          NaN
# 698                          NaN
# 699  Randomized Controlled Trial
#
#                                    Program Description  \
# 0    Program Goals\nThe San Francisco Behavioral He...
# 1    Program note: The Forever Free program was clo...
# 2    Program Goals\nStrong African American Familie...
# 3    Program Goals\nThe Boston Reentry Initiative (...
# 4    Program Goals\nChild and Family Traumatic Stre...
# ..                                                 ...
# 695  Program Goals\nRestorative justice practices a...
# 696  Program Goals/Target Sites\nA geographically b...
# 697  Program Goals\nThe 24/7 Sobriety Program was o...
# 698  Program Goals\nThe Supervision with Immediate ...
# 699  Program Goals/Target Population\nTake CHARGE! ...
#
#                               Program Description HTML  \
# 0    <h3>Program Goals</h3>\n<p>The San Francisco B...
# 1    <p><strong>Program note:</strong> The Forever ...
# 2    <h3>Program Goals</h3>\n<p>Strong African Amer...
# 3    <h3>Program Goals</h3>\n<p>The Boston Reentry ...
# 4    <h3>Program Goals</h3>\n<p>Child and Family Tr...
# ..                                                 ...
# 695  <h3>Program Goals</h3>\n<p>Restorative justice...
# 696  <h3>Program Goals/Target Sites</h3>\n<p>A geog...
# 697  <h3><strong>Program Goals</strong></h3>\n<p>Th...
# 698  <h3>Program Goals</h3>\n<p>The Supervision wit...
# 699  <h3>Program Goals/Target Population</h3>\n<p>T...
#
#                                 Evaluation Methodology  ...  \
# 0    Study 1\nMcNiel and Binder (2007) used a retro...  ...
# 1    Study 1\nA program evaluation by Hall and coll...  ...
# 2    Study 1\nBrody and colleagues (2006) evaluated...  ...
# 3    Study 1\nThe study by Braga, Piehl, and Hureau...  ...
# 4    Study 1\nBerkowitz, Stover, and Marans (2010) ...  ...
# ..                                                 ...  ...
# 695  Study 1\nLiberman and Katz (2021) used a quasi...  ...
# 696  Study 1\nKochel, Nouri, and Samadi (2022) cond...  ...
# 697  Study 1\nMidgette and colleagues (2021) assess...  ...
# 698  Study 1\nBoots and colleagues (2018) used a qu...  ...
# 699  Study 1\nVan Loan and colleagues (2019) used a...  ...
#
#                                               Contacts  \
# 0    <p><strong><label id="Program Director">Progra...
# 1    <p><strong><label id="Program Developer">Progr...
# 2    <p><strong><label id="Program Developer">Progr...
# 3    <p><strong><label id="Program Director">Progra...
# 4    <p><strong><label id="Program Developer">Progr...
# ..                                                 ...
# 695                                                NaN
# 696  <p><strong><label id="Program Director">Progra...
# 697  <p><strong><label id="Program Director">Progra...
# 698                                                NaN
# 699                                                NaN
#
#                                      Related Practices       DatePostedPublic  \
# 0    <a href=PracticeDetails.aspx?ID=34><b>Adult Me...   6/8/2011 10:40:33 AM
# 1    <a href=PracticeDetails.aspx?ID=52><b>Incarcer...    6/8/2011 1:47:40 PM
# 2    <a href=PracticeDetails.aspx?ID=116><b>Psychos...  6/10/2011 12:52:20 PM
# 3    <a href=PracticeDetails.aspx?ID=15><b>Mentorin...   6/10/2011 1:41:49 PM
# 4                                                  NaN   6/14/2011 2:34:50 PM
# ..                                                 ...                    ...
# 695  <a href=PracticeDetails.aspx?ID=70><b>Restorat...   7/24/2023 7:17:27 AM
# 696  <a href=PracticeDetails.aspx?ID=11><b>Focused ...    8/2/2023 6:20:03 AM
# 697                                                NaN   8/15/2023 1:17:19 PM
# 698  <a href=PracticeDetails.aspx?ID=101><b>Rehabil...   8/15/2023 9:33:12 AM
# 699                                                NaN   8/23/2023 7:03:05 AM
#
#                                      Other Information  \
# 0    McNiel and Binder (2007) reported that statist...
# 1    <p>Subgroup Analysis</h3><p>\nWith regards to ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 695                                                NaN
# 696                                                NaN
# 697  For more information about the 24/7 Sobriety P...
# 698                                                NaN
# 699                                                NaN
#
#                                             Topics MPG  \
# 0    |Crime & Crime Prevention|Courts|Mental Health...
# 1    |Crime & Crime Prevention|Corrections & Reentr...
# 2    |Drugs & Substance Abuse|Juveniles|Prevention ...
# 3    |Corrections & Reentry|Community Corrections|I...
# 4    |Juveniles|Victims & Victimization|Children Ex...
# ..                                                 ...
# 695  |Juveniles|Victims & Victimization|Child Prote...
# 696  |Crime & Crime Prevention|Law Enforcement|Vict...
# 697  |Crime & Crime Prevention|Corrections & Reentr...
# 698  |Crime & Crime Prevention|Corrections & Reentr...
# 699  |Juveniles|Child Protection/Health  |Delinquen...
#
#                                                Factors  \
# 0                                                  NaN
# 1                                                  NaN
# 2    |Availability of alcohol and other drugs|Peer ...
# 3                                                  NaN
# 4    |Nondisadvantaged neighborhood|Safe environmen...
# ..                                                 ...
# 695  |Association with delinquent/aggressive peers|...
# 696                                                NaN
# 697                                                NaN
# 698                                                NaN
# 699  |Antisocial behavior and alienation/delinquent...
#
#                                              Topic IDs  \
# 0                               ~1~3~18~48~49~220~241~
# 1        ~1~2~4~11~28~31~36~53~59~106~166~177~190~272~
# 2    ~4~5~55~61~62~63~69~258~261~285~286~289~446~45...
# 3    ~2~28~31~32~35~36~166~167~177~178~179~180~181~...
# 4    ~5~8~60~61~94~95~98~275~282~283~400~401~403~40...
# ..                                                 ...
# 695                ~5~8~61~62~67~70~72~99~291~454~474~
# 696             ~1~6~8~10~13~25~84~94~109~144~363~408~
# 697  ~1~2~3~4~6~7~11~25~26~28~34~35~46~48~53~55~56~...
# 698                    ~1~2~3~13~28~35~49~164~167~188~
# 699                ~5~61~62~69~70~283~291~455~460~474~
#
#                                          Factor IDs Multisite  \
# 0                                               NaN       NaN
# 1                                               NaN       NaN
# 2        ~1~11~25~26~40~45~56~68~69~72~74~77~78~81~       NaN
# 3                                               NaN       NaN
# 4    ~50~51~52~54~56~68~69~70~71~72~74~76~77~78~79~       NaN
# ..                                              ...       ...
# 695  ~12~16~17~19~30~31~37~41~58~60~61~65~70~76~81~       NaN
# 696                                             NaN       NaN
# 697                                             NaN       NaN
# 698                                             NaN       NaN
# 699                    ~37~41~47~49~63~74~76~78~81~       NaN
#
#                                        Semaphore Terms
# 0    [{"id":"29128c54-945f-5aee-8f7e-58c4655d3687",...
# 1    [{"id":"2c7af3b8-0c0e-5103-bc79-01ea141ad86c",...
# 2    [{"id":"042f9d9b-b882-4c35-ae98-248ddca40128",...
# 3    [{"id":"23501706-979e-5185-8d16-99e35c0dcfd7",...
# 4    [{"id":"02f0130e-50d0-537b-a97a-d7df9b6e2002",...
# ..                                                 ...
# 695  [{"id":"3827f871-7884-5c2f-9ec8-d48918db707b",...
# 696  [{"id":"46b10125-1d65-4814-b67d-be3c1a522d7e",...
# 697  [{"id":"015ad61e-17f1-532f-a094-1bfab5ac020c",...
# 698  [{"id":"015ad61e-17f1-532f-a094-1bfab5ac020c",...
# 699  [{"id":"042f9d9b-b882-4c35-ae98-248ddca40128",...
#
# [700 rows x 37 columns]

# %%
import pandas as pd

df_remove = df

def readd_first_three_cols(df_remove):
    # Store the first 3 columns
    first_three_cols = df_remove.iloc[:, :3]

    # Delete the first 3 columns
    df_remove = df_remove.iloc[:, 3:]

    return df_remove

print("Original DataFrame:")
print(df)

df_remove = readd_first_three_cols(df_remove)
print("\nDataFrame with first 3 columns deleted:")
print(df_remove)
# Out:
# Original DataFrame:
#      InterventionPublic_ID  Intervention_ID  \
# 0                     7531               39
# 1                     7558               40
# 2                     6028               41
# 3                     7105               42
# 4                     7110               43
# ..                     ...              ...
# 695                   7792             1795
# 696                   7787             1796
# 697                   7795             1797
# 698                   7794             1798
# 699                   7798             1799
#
#                                                  Title  \
# 0    Program Profile: San Francisco (Calif.) Behavi...
# 1                        Program Profile: Forever Free
# 2    Program Profile: Strong African American Famil...
# 3    Program Profile: Boston (Massachusetts) Reentr...
# 4    Program Profile: Child and Family Traumatic St...
# ..                                                 ...
# 695  Program Profile: Restorative Justice Conferenc...
# 696  Program Profile: Geographically Based Focused ...
# 697  Program Profile: North Dakota’s 24/7 Sobriety ...
# 698  Program Profile: Supervision with Immediate En...
# 699  Program Profile: Take CHARGE! Curriculum for S...
#
#                      Evidence Rating  \
# 0              Promising - One study
# 1              Promising - One study
# 2    Effective - More than one study
# 3              Promising - One study
# 4              Promising - One study
# ..                               ...
# 695           No Effects - One study
# 696            Promising - One study
# 697            Promising - One study
# 698            Promising - One study
# 699            Effective - One study
#
#                                                 Topics  \
# 0                     Courts, Crime & Crime Prevention
# 1    Corrections & Reentry, Crime & Crime Preventio...
# 2                   Drugs & Substance Abuse, Juveniles
# 3                                Corrections & Reentry
# 4                   Juveniles, Victims & Victimization
# ..                                                 ...
# 695                 Juveniles, Victims & Victimization
# 696  Crime & Crime Prevention, Law Enforcement, Vic...
# 697  Corrections & Reentry, Courts, Crime & Crime P...
# 698  Corrections & Reentry, Courts, Crime & Crime P...
# 699                                          Juveniles
#
#                                                Summary  \
# 0    The court aims to connect defendants with seri...
# 1    This prison-based substance abuse treatment pr...
# 2    This is a parental training and family therapy...
# 3    This interagency public safety initiative aims...
# 4    This is a brief early intervention and seconda...
# ..                                                 ...
# 695  This is a school program to address student mi...
# 696  This was a focused deterrence intervention des...
# 697  This program seeks to reduce the rearrests of ...
# 698  This is a specialized court program that targe...
# 699  This is a curriculum that targets students wit...
#
#      Randomized Controlled Trial  \
# 0                            NaN
# 1                            NaN
# 2    Randomized Controlled Trial
# 3                            NaN
# 4    Randomized Controlled Trial
# ..                           ...
# 695                          NaN
# 696                          NaN
# 697                          NaN
# 698                          NaN
# 699  Randomized Controlled Trial
#
#                                    Program Description  \
# 0    Program Goals\nThe San Francisco Behavioral He...
# 1    Program note: The Forever Free program was clo...
# 2    Program Goals\nStrong African American Familie...
# 3    Program Goals\nThe Boston Reentry Initiative (...
# 4    Program Goals\nChild and Family Traumatic Stre...
# ..                                                 ...
# 695  Program Goals\nRestorative justice practices a...
# 696  Program Goals/Target Sites\nA geographically b...
# 697  Program Goals\nThe 24/7 Sobriety Program was o...
# 698  Program Goals\nThe Supervision with Immediate ...
# 699  Program Goals/Target Population\nTake CHARGE! ...
#
#                               Program Description HTML  \
# 0    <h3>Program Goals</h3>\n<p>The San Francisco B...
# 1    <p><strong>Program note:</strong> The Forever ...
# 2    <h3>Program Goals</h3>\n<p>Strong African Amer...
# 3    <h3>Program Goals</h3>\n<p>The Boston Reentry ...
# 4    <h3>Program Goals</h3>\n<p>Child and Family Tr...
# ..                                                 ...
# 695  <h3>Program Goals</h3>\n<p>Restorative justice...
# 696  <h3>Program Goals/Target Sites</h3>\n<p>A geog...
# 697  <h3><strong>Program Goals</strong></h3>\n<p>Th...
# 698  <h3>Program Goals</h3>\n<p>The Supervision wit...
# 699  <h3>Program Goals/Target Population</h3>\n<p>T...
#
#                                 Evaluation Methodology  ...  \
# 0    Study 1\nMcNiel and Binder (2007) used a retro...  ...
# 1    Study 1\nA program evaluation by Hall and coll...  ...
# 2    Study 1\nBrody and colleagues (2006) evaluated...  ...
# 3    Study 1\nThe study by Braga, Piehl, and Hureau...  ...
# 4    Study 1\nBerkowitz, Stover, and Marans (2010) ...  ...
# ..                                                 ...  ...
# 695  Study 1\nLiberman and Katz (2021) used a quasi...  ...
# 696  Study 1\nKochel, Nouri, and Samadi (2022) cond...  ...
# 697  Study 1\nMidgette and colleagues (2021) assess...  ...
# 698  Study 1\nBoots and colleagues (2018) used a qu...  ...
# 699  Study 1\nVan Loan and colleagues (2019) used a...  ...
#
#                                               Contacts  \
# 0    <p><strong><label id="Program Director">Progra...
# 1    <p><strong><label id="Program Developer">Progr...
# 2    <p><strong><label id="Program Developer">Progr...
# 3    <p><strong><label id="Program Director">Progra...
# 4    <p><strong><label id="Program Developer">Progr...
# ..                                                 ...
# 695                                                NaN
# 696  <p><strong><label id="Program Director">Progra...
# 697  <p><strong><label id="Program Director">Progra...
# 698                                                NaN
# 699                                                NaN
#
#                                      Related Practices       DatePostedPublic  \
# 0    <a href=PracticeDetails.aspx?ID=34><b>Adult Me...   6/8/2011 10:40:33 AM
# 1    <a href=PracticeDetails.aspx?ID=52><b>Incarcer...    6/8/2011 1:47:40 PM
# 2    <a href=PracticeDetails.aspx?ID=116><b>Psychos...  6/10/2011 12:52:20 PM
# 3    <a href=PracticeDetails.aspx?ID=15><b>Mentorin...   6/10/2011 1:41:49 PM
# 4                                                  NaN   6/14/2011 2:34:50 PM
# ..                                                 ...                    ...
# 695  <a href=PracticeDetails.aspx?ID=70><b>Restorat...   7/24/2023 7:17:27 AM
# 696  <a href=PracticeDetails.aspx?ID=11><b>Focused ...    8/2/2023 6:20:03 AM
# 697                                                NaN   8/15/2023 1:17:19 PM
# 698  <a href=PracticeDetails.aspx?ID=101><b>Rehabil...   8/15/2023 9:33:12 AM
# 699                                                NaN   8/23/2023 7:03:05 AM
#
#                                      Other Information  \
# 0    McNiel and Binder (2007) reported that statist...
# 1    <p>Subgroup Analysis</h3><p>\nWith regards to ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 695                                                NaN
# 696                                                NaN
# 697  For more information about the 24/7 Sobriety P...
# 698                                                NaN
# 699                                                NaN
#
#                                             Topics MPG  \
# 0    |Crime & Crime Prevention|Courts|Mental Health...
# 1    |Crime & Crime Prevention|Corrections & Reentr...
# 2    |Drugs & Substance Abuse|Juveniles|Prevention ...
# 3    |Corrections & Reentry|Community Corrections|I...
# 4    |Juveniles|Victims & Victimization|Children Ex...
# ..                                                 ...
# 695  |Juveniles|Victims & Victimization|Child Prote...
# 696  |Crime & Crime Prevention|Law Enforcement|Vict...
# 697  |Crime & Crime Prevention|Corrections & Reentr...
# 698  |Crime & Crime Prevention|Corrections & Reentr...
# 699  |Juveniles|Child Protection/Health  |Delinquen...
#
#                                                Factors  \
# 0                                                  NaN
# 1                                                  NaN
# 2    |Availability of alcohol and other drugs|Peer ...
# 3                                                  NaN
# 4    |Nondisadvantaged neighborhood|Safe environmen...
# ..                                                 ...
# 695  |Association with delinquent/aggressive peers|...
# 696                                                NaN
# 697                                                NaN
# 698                                                NaN
# 699  |Antisocial behavior and alienation/delinquent...
#
#                                              Topic IDs  \
# 0                               ~1~3~18~48~49~220~241~
# 1        ~1~2~4~11~28~31~36~53~59~106~166~177~190~272~
# 2    ~4~5~55~61~62~63~69~258~261~285~286~289~446~45...
# 3    ~2~28~31~32~35~36~166~167~177~178~179~180~181~...
# 4    ~5~8~60~61~94~95~98~275~282~283~400~401~403~40...
# ..                                                 ...
# 695                ~5~8~61~62~67~70~72~99~291~454~474~
# 696             ~1~6~8~10~13~25~84~94~109~144~363~408~
# 697  ~1~2~3~4~6~7~11~25~26~28~34~35~46~48~53~55~56~...
# 698                    ~1~2~3~13~28~35~49~164~167~188~
# 699                ~5~61~62~69~70~283~291~455~460~474~
#
#                                          Factor IDs Multisite  \
# 0                                               NaN       NaN
# 1                                               NaN       NaN
# 2        ~1~11~25~26~40~45~56~68~69~72~74~77~78~81~       NaN
# 3                                               NaN       NaN
# 4    ~50~51~52~54~56~68~69~70~71~72~74~76~77~78~79~       NaN
# ..                                              ...       ...
# 695  ~12~16~17~19~30~31~37~41~58~60~61~65~70~76~81~       NaN
# 696                                             NaN       NaN
# 697                                             NaN       NaN
# 698                                             NaN       NaN
# 699                    ~37~41~47~49~63~74~76~78~81~       NaN
#
#                                        Semaphore Terms
# 0    [{"id":"29128c54-945f-5aee-8f7e-58c4655d3687",...
# 1    [{"id":"2c7af3b8-0c0e-5103-bc79-01ea141ad86c",...
# 2    [{"id":"042f9d9b-b882-4c35-ae98-248ddca40128",...
# 3    [{"id":"23501706-979e-5185-8d16-99e35c0dcfd7",...
# 4    [{"id":"02f0130e-50d0-537b-a97a-d7df9b6e2002",...
# ..                                                 ...
# 695  [{"id":"3827f871-7884-5c2f-9ec8-d48918db707b",...
# 696  [{"id":"46b10125-1d65-4814-b67d-be3c1a522d7e",...
# 697  [{"id":"015ad61e-17f1-532f-a094-1bfab5ac020c",...
# 698  [{"id":"015ad61e-17f1-532f-a094-1bfab5ac020c",...
# 699  [{"id":"042f9d9b-b882-4c35-ae98-248ddca40128",...
#
# [700 rows x 37 columns]
#
# DataFrame with first 3 columns deleted:
#                      Evidence Rating  \
# 0              Promising - One study
# 1              Promising - One study
# 2    Effective - More than one study
# 3              Promising - One study
# 4              Promising - One study
# ..                               ...
# 695           No Effects - One study
# 696            Promising - One study
# 697            Promising - One study
# 698            Promising - One study
# 699            Effective - One study
#
#                                                 Topics  \
# 0                     Courts, Crime & Crime Prevention
# 1    Corrections & Reentry, Crime & Crime Preventio...
# 2                   Drugs & Substance Abuse, Juveniles
# 3                                Corrections & Reentry
# 4                   Juveniles, Victims & Victimization
# ..                                                 ...
# 695                 Juveniles, Victims & Victimization
# 696  Crime & Crime Prevention, Law Enforcement, Vic...
# 697  Corrections & Reentry, Courts, Crime & Crime P...
# 698  Corrections & Reentry, Courts, Crime & Crime P...
# 699                                          Juveniles
#
#                                                Summary  \
# 0    The court aims to connect defendants with seri...
# 1    This prison-based substance abuse treatment pr...
# 2    This is a parental training and family therapy...
# 3    This interagency public safety initiative aims...
# 4    This is a brief early intervention and seconda...
# ..                                                 ...
# 695  This is a school program to address student mi...
# 696  This was a focused deterrence intervention des...
# 697  This program seeks to reduce the rearrests of ...
# 698  This is a specialized court program that targe...
# 699  This is a curriculum that targets students wit...
#
#      Randomized Controlled Trial  \
# 0                            NaN
# 1                            NaN
# 2    Randomized Controlled Trial
# 3                            NaN
# 4    Randomized Controlled Trial
# ..                           ...
# 695                          NaN
# 696                          NaN
# 697                          NaN
# 698                          NaN
# 699  Randomized Controlled Trial
#
#                                    Program Description  \
# 0    Program Goals\nThe San Francisco Behavioral He...
# 1    Program note: The Forever Free program was clo...
# 2    Program Goals\nStrong African American Familie...
# 3    Program Goals\nThe Boston Reentry Initiative (...
# 4    Program Goals\nChild and Family Traumatic Stre...
# ..                                                 ...
# 695  Program Goals\nRestorative justice practices a...
# 696  Program Goals/Target Sites\nA geographically b...
# 697  Program Goals\nThe 24/7 Sobriety Program was o...
# 698  Program Goals\nThe Supervision with Immediate ...
# 699  Program Goals/Target Population\nTake CHARGE! ...
#
#                               Program Description HTML  \
# 0    <h3>Program Goals</h3>\n<p>The San Francisco B...
# 1    <p><strong>Program note:</strong> The Forever ...
# 2    <h3>Program Goals</h3>\n<p>Strong African Amer...
# 3    <h3>Program Goals</h3>\n<p>The Boston Reentry ...
# 4    <h3>Program Goals</h3>\n<p>Child and Family Tr...
# ..                                                 ...
# 695  <h3>Program Goals</h3>\n<p>Restorative justice...
# 696  <h3>Program Goals/Target Sites</h3>\n<p>A geog...
# 697  <h3><strong>Program Goals</strong></h3>\n<p>Th...
# 698  <h3>Program Goals</h3>\n<p>The Supervision wit...
# 699  <h3>Program Goals/Target Population</h3>\n<p>T...
#
#                                 Evaluation Methodology  \
# 0    Study 1\nMcNiel and Binder (2007) used a retro...
# 1    Study 1\nA program evaluation by Hall and coll...
# 2    Study 1\nBrody and colleagues (2006) evaluated...
# 3    Study 1\nThe study by Braga, Piehl, and Hureau...
# 4    Study 1\nBerkowitz, Stover, and Marans (2010) ...
# ..                                                 ...
# 695  Study 1\nLiberman and Katz (2021) used a quasi...
# 696  Study 1\nKochel, Nouri, and Samadi (2022) cond...
# 697  Study 1\nMidgette and colleagues (2021) assess...
# 698  Study 1\nBoots and colleagues (2018) used a qu...
# 699  Study 1\nVan Loan and colleagues (2019) used a...
#
#                            Evaluation Methodology HTML  \
# 0    <h3>Study 1</h3>\n<p>McNiel and Binder (2007) ...
# 1    <h3>Study 1</h3>\n<p>A program evaluation by H...
# 2    <h3>Study 1</h3>\n<p>Brody and colleagues (200...
# 3    <h3>Study 1</h3>\n<p>The study by Braga, Piehl...
# 4    <h3>Study 1</h3>\n<p>Berkowitz, Stover, and Ma...
# ..                                                 ...
# 695  <h3>Study 1</h3>\n<p>Liberman and Katz (2021) ...
# 696  <h3>Study 1</h3>\n<p>Kochel, Nouri, and Samadi...
# 697  <h3><strong>Study 1</strong></h3>\n<p>Midgette...
# 698  <h3>Study 1</h3>\n<p>Boots and colleagues (201...
# 699  <h3>Study 1</h3>\n<p>Van Loan and colleagues (...
#
#                                    Evaluation Outcomes  \
# 0    Study 1\nNew Charges\nMcNiel and Binder (2007)...
# 1    Study 1\nOverall, Hall and colleagues (2004) f...
# 2    Study 1\nChild Alcohol Use\nBrody and colleagu...
# 3    Study 1\nArrests for Any Crimes\nThe first ana...
# 4    Study 1\nPTSD Diagnosis\nBerkowitz, Stover, an...
# ..                                                 ...
# 695  Study 1\nMiddle School Referrals for a Variety...
# 696  Study 1\nConfirmed Shots Fired\nKochel, Nouri,...
# 697  Study 1\nDUI Arrest Rates\nMidgette and collea...
# 698  Study 1\nProbation Revocation\nBoots and colle...
# 699  Study 1\nApproaches to Problem-Solving\nVan Lo...
#
#                               Evaluation Outcomes HTML  ...  \
# 0    <h3>Study 1</h3>\n<h3>New Charges</h3>\n<p>McN...  ...
# 1    <h3>Study 1</h3>\n<p>Overall, Hall and colleag...  ...
# 2    <h3>Study 1</h3>\n<h3>Child Alcohol Use</h3>\n...  ...
# 3    <h3>Study 1</h3>\n<h4>Arrests for Any Crimes</...  ...
# 4    <h3>Study 1</h3>\n<h4>PTSD Diagnosis</h4>\n<p>...  ...
# ..                                                 ...  ...
# 695  <h3>Study 1</h3>\n<h3>Middle School Referrals ...  ...
# 696  <h3>Study 1</h3>\n<h3>Confirmed Shots Fired</h...  ...
# 697  <h3>Study 1</h3>\n<p><strong>DUI Arrest Rates<...  ...
# 698  <h3>Study 1</h3>\n<h3>Probation Revocation</h3...  ...
# 699  <h3>Study 1</h3>\n<h3>Approaches to Problem-So...  ...
#
#                                               Contacts  \
# 0    <p><strong><label id="Program Director">Progra...
# 1    <p><strong><label id="Program Developer">Progr...
# 2    <p><strong><label id="Program Developer">Progr...
# 3    <p><strong><label id="Program Director">Progra...
# 4    <p><strong><label id="Program Developer">Progr...
# ..                                                 ...
# 695                                                NaN
# 696  <p><strong><label id="Program Director">Progra...
# 697  <p><strong><label id="Program Director">Progra...
# 698                                                NaN
# 699                                                NaN
#
#                                      Related Practices       DatePostedPublic  \
# 0    <a href=PracticeDetails.aspx?ID=34><b>Adult Me...   6/8/2011 10:40:33 AM
# 1    <a href=PracticeDetails.aspx?ID=52><b>Incarcer...    6/8/2011 1:47:40 PM
# 2    <a href=PracticeDetails.aspx?ID=116><b>Psychos...  6/10/2011 12:52:20 PM
# 3    <a href=PracticeDetails.aspx?ID=15><b>Mentorin...   6/10/2011 1:41:49 PM
# 4                                                  NaN   6/14/2011 2:34:50 PM
# ..                                                 ...                    ...
# 695  <a href=PracticeDetails.aspx?ID=70><b>Restorat...   7/24/2023 7:17:27 AM
# 696  <a href=PracticeDetails.aspx?ID=11><b>Focused ...    8/2/2023 6:20:03 AM
# 697                                                NaN   8/15/2023 1:17:19 PM
# 698  <a href=PracticeDetails.aspx?ID=101><b>Rehabil...   8/15/2023 9:33:12 AM
# 699                                                NaN   8/23/2023 7:03:05 AM
#
#                                      Other Information  \
# 0    McNiel and Binder (2007) reported that statist...
# 1    <p>Subgroup Analysis</h3><p>\nWith regards to ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 695                                                NaN
# 696                                                NaN
# 697  For more information about the 24/7 Sobriety P...
# 698                                                NaN
# 699                                                NaN
#
#                                             Topics MPG  \
# 0    |Crime & Crime Prevention|Courts|Mental Health...
# 1    |Crime & Crime Prevention|Corrections & Reentr...
# 2    |Drugs & Substance Abuse|Juveniles|Prevention ...
# 3    |Corrections & Reentry|Community Corrections|I...
# 4    |Juveniles|Victims & Victimization|Children Ex...
# ..                                                 ...
# 695  |Juveniles|Victims & Victimization|Child Prote...
# 696  |Crime & Crime Prevention|Law Enforcement|Vict...
# 697  |Crime & Crime Prevention|Corrections & Reentr...
# 698  |Crime & Crime Prevention|Corrections & Reentr...
# 699  |Juveniles|Child Protection/Health  |Delinquen...
#
#                                                Factors  \
# 0                                                  NaN
# 1                                                  NaN
# 2    |Availability of alcohol and other drugs|Peer ...
# 3                                                  NaN
# 4    |Nondisadvantaged neighborhood|Safe environmen...
# ..                                                 ...
# 695  |Association with delinquent/aggressive peers|...
# 696                                                NaN
# 697                                                NaN
# 698                                                NaN
# 699  |Antisocial behavior and alienation/delinquent...
#
#                                              Topic IDs  \
# 0                               ~1~3~18~48~49~220~241~
# 1        ~1~2~4~11~28~31~36~53~59~106~166~177~190~272~
# 2    ~4~5~55~61~62~63~69~258~261~285~286~289~446~45...
# 3    ~2~28~31~32~35~36~166~167~177~178~179~180~181~...
# 4    ~5~8~60~61~94~95~98~275~282~283~400~401~403~40...
# ..                                                 ...
# 695                ~5~8~61~62~67~70~72~99~291~454~474~
# 696             ~1~6~8~10~13~25~84~94~109~144~363~408~
# 697  ~1~2~3~4~6~7~11~25~26~28~34~35~46~48~53~55~56~...
# 698                    ~1~2~3~13~28~35~49~164~167~188~
# 699                ~5~61~62~69~70~283~291~455~460~474~
#
#                                          Factor IDs Multisite  \
# 0                                               NaN       NaN
# 1                                               NaN       NaN
# 2        ~1~11~25~26~40~45~56~68~69~72~74~77~78~81~       NaN
# 3                                               NaN       NaN
# 4    ~50~51~52~54~56~68~69~70~71~72~74~76~77~78~79~       NaN
# ..                                              ...       ...
# 695  ~12~16~17~19~30~31~37~41~58~60~61~65~70~76~81~       NaN
# 696                                             NaN       NaN
# 697                                             NaN       NaN
# 698                                             NaN       NaN
# 699                    ~37~41~47~49~63~74~76~78~81~       NaN
#
#                                        Semaphore Terms
# 0    [{"id":"29128c54-945f-5aee-8f7e-58c4655d3687",...
# 1    [{"id":"2c7af3b8-0c0e-5103-bc79-01ea141ad86c",...
# 2    [{"id":"042f9d9b-b882-4c35-ae98-248ddca40128",...
# 3    [{"id":"23501706-979e-5185-8d16-99e35c0dcfd7",...
# 4    [{"id":"02f0130e-50d0-537b-a97a-d7df9b6e2002",...
# ..                                                 ...
# 695  [{"id":"3827f871-7884-5c2f-9ec8-d48918db707b",...
# 696  [{"id":"46b10125-1d65-4814-b67d-be3c1a522d7e",...
# 697  [{"id":"015ad61e-17f1-532f-a094-1bfab5ac020c",...
# 698  [{"id":"015ad61e-17f1-532f-a094-1bfab5ac020c",...
# 699  [{"id":"042f9d9b-b882-4c35-ae98-248ddca40128",...
#
# [700 rows x 34 columns]

# %%
def compare_columns(df, df_remove):
    """
    Compares the columns of two DataFrames and prints the differences.

    Args:
        df1: The first DataFrame.
        df2: The second DataFrame.
    """
    cols1 = set(df.columns)
    cols2 = set(df_remove.columns)

    added_cols = cols2 - cols1
    removed_cols = cols1 - cols2
    common_cols = cols1.intersection(cols2)

    print("Columns missing that are needed to answer query:", removed_cols)



compare_columns(df, df_remove)
# Out:
# Columns missing that are needed to answer query: {'Intervention_ID', 'InterventionPublic_ID', 'Title'}

# %%
# List of required column names
required_columns =  df.iloc[:, :3]

# Check for missing columns and print a message
missing_columns = [col for col in required_columns if col not in df.columns]

if missing_columns:
    print(f"Error: The following required columns are missing from the DataFrame: {missing_columns}")
else:
    print("All required columns are now present in the DataFrame. The query can be answered.")
# Out:
# All required columns are now present in the DataFrame. The query can be answered.

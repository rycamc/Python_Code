# %%
import pandas as pd
from google.colab import drive
import numpy as np
from datetime import datetime

drive.mount('/content/drive')

path = '/content/drive/MyDrive/Marijuana_Arrests.csv'

import pandas as pd
df = pd.read_csv(path)
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                        TYPE ADULT_JUVENILE  YEAR  \
# 0                                Possession          Adult  2012
# 1                                Possession          Adult  2012
# 2                                Possession          Adult  2012
# 3                                Possession          Adult  2012
# 4      Possession with intent to distribute          Adult  2012
# ...                                     ...            ...   ...
# 14040                            Possession       Juvenile  2023
# 14041  Possession with intent to distribute       Juvenile  2023
# 14042  Possession with intent to distribute       Juvenile  2023
# 14043                          Distribution       Juvenile  2023
# 14044  Possession with intent to distribute       Juvenile  2023
#
#                      DATETIME                              CCN   AGE  \
# 0      2012/01/01 06:00:00+00                 b';\xc8k~\xa4iJ'  20.0
# 1      2012/01/01 06:00:00+00                 b';\xc8k~\xa4iJ'  23.0
# 2      2012/01/01 06:00:00+00           b't6\xa0\xac\xec`\xa4'  46.0
# 3      2012/01/01 09:35:00+00        b'\xbe\x1d\xa7\xf5\xffWx'  30.0
# 4      2012/01/02 19:40:00+00  b'\xbb\xc0\x8e\x94\x81\xac\xcd'  29.0
# ...                       ...                              ...   ...
# 14040  2023/10/26 04:00:00+00                              NaN   NaN
# 14041  2023/12/07 05:00:00+00                              NaN   NaN
# 14042  2023/12/16 05:00:00+00                              NaN   NaN
# 14043  2023/12/19 05:00:00+00                              NaN   NaN
# 14044  2023/12/30 05:00:00+00                              NaN   NaN
#
#       OFFENSE_DISTRICT  OFFENSE_PSA  OFFENSE_BLOCKX  OFFENSE_BLOCKY  ...  \
# 0                   5D        501.0        399700.0        137900.0  ...
# 1                   5D        501.0        399700.0        137900.0  ...
# 2                   7D        707.0        399700.0        130600.0  ...
# 3                   6D        605.0        403300.0        134500.0  ...
# 4                   6D        604.0        406400.0        135300.0  ...
# ...                ...          ...             ...             ...  ...
# 14040               3D        303.0             NaN             NaN  ...
# 14041               6D        601.0             NaN             NaN  ...
# 14042               6D        608.0             NaN             NaN  ...
# 14043               7D        708.0             NaN             NaN  ...
# 14044               6D        607.0             NaN             NaN  ...
#
#                             ADDRESS ARREST_BLOCKX ARREST_BLOCKY  \
# 0                    FLORIDA AVE NE      401400.0      136900.0
# 1                    FLORIDA AVE NE      401400.0      136900.0
# 2      3300 BLOCK OF BROTHERS PL SE      399700.0      130600.0
# 3           700 BLOCK OF 32ND ST SE           NaN           NaN
# 4             5300 BLOCK OF B ST SE           NaN           NaN
# ...                             ...           ...           ...
# 14040                215 MANSION RD           NaN           NaN
# 14041          315 THOROUGHBRED AVE           NaN           NaN
# 14042                  204 DORIS Pl           NaN           NaN
# 14043       MARTIN LUTHER KING BLVD           NaN           NaN
# 14044                  8 WILLIOW WY           NaN           NaN
#
#                         GIS_ID CREATOR                 CREATED EDITOR  \
# 0      MARIJUANA_ARRESTS_12481    JLAY  2022/10/18 21:51:23+00   JLAY
# 1      MARIJUANA_ARRESTS_12482    JLAY  2022/10/18 21:51:23+00   JLAY
# 2      MARIJUANA_ARRESTS_12483    JLAY  2022/10/18 21:51:23+00   JLAY
# 3      MARIJUANA_ARRESTS_12484    JLAY  2022/10/18 21:51:23+00   JLAY
# 4      MARIJUANA_ARRESTS_12485    JLAY  2022/10/18 21:51:23+00   JLAY
# ...                        ...     ...                     ...    ...
# 14040  MARIJUANA_ARRESTS_27664    JLAY  2024/05/30 22:31:49+00   JLAY
# 14041  MARIJUANA_ARRESTS_27665    JLAY  2024/05/30 22:31:49+00   JLAY
# 14042  MARIJUANA_ARRESTS_27666    JLAY  2024/05/30 22:31:49+00   JLAY
# 14043  MARIJUANA_ARRESTS_27667    JLAY  2024/05/30 22:31:49+00   JLAY
# 14044  MARIJUANA_ARRESTS_27668    JLAY  2024/05/30 22:31:49+00   JLAY
#
#                        EDITED  OBJECTID  \
# 0      2024/05/30 22:47:09+00     12481
# 1      2024/05/30 22:47:09+00     12482
# 2      2024/05/30 22:47:09+00     12483
# 3      2024/05/30 22:47:09+00     12484
# 4      2024/05/30 22:47:09+00     12485
# ...                       ...       ...
# 14040  2024/05/30 22:47:09+00     27664
# 14041  2024/05/30 22:47:09+00     27665
# 14042  2024/05/30 22:47:09+00     27666
# 14043  2024/05/30 22:47:09+00     27667
# 14044  2024/05/30 22:47:09+00     27668
#
#                                      GLOBALID
# 0      {4654D30A-5B56-4E19-8FC2-B19CC723C747}
# 1      {1C0EBA86-27EC-4B8E-8ABB-6EFFF03A0AA2}
# 2      {88080D68-CFA3-41E6-AA69-5DB7F950A134}
# 3      {7769980A-5F36-4B3C-91CF-D1A3A94CE52E}
# 4      {5D5BEE85-DF16-41A1-BB49-0D16D0EE1320}
# ...                                       ...
# 14040  {D0CABACE-FAE3-4F40-BFF2-4D698CFEDAB1}
# 14041  {547A3AD2-809C-46F8-B251-2BEB5C121C7A}
# 14042  {C6BC98AA-B9F2-4E81-954B-0D04D1FF24C9}
# 14043  {3A441C0C-C10E-48F5-83A0-806D22A046CF}
# 14044  {6AE10201-674B-4198-BB78-EA83007AE6A4}
#
# [14045 rows x 27 columns]

# %%
import pandas as pd
import re
import numpy as np

def find_address_column(df):
    address_pattern = re.compile(r'\b\d+\s+\w+\s+(?:way|place|drive|lane|street|avenue|road|boulevard|wy|pl|dr|ln|st|ave|rd|blvd||Wy|Pl|St|Ave|Rd|Blvd|Dr|Ln|DRIVE|WAY|PLACE|LANE|STREET|AVENUE|BOULEVARD|ROAD|ST|DR|LN|WY|PL|AVE|RD|Way|Place|Drive|Lane|Boulevard|Street|Avenue|Road)\b', re.IGNORECASE)
    for column in df.columns:
        if df[column].astype(str).str.contains(address_pattern).any():
            return column
    return None


address_column = find_address_column(df)
if address_column:
    print(f"Address column found: {address_column}")
else:
    print("No address column found.")
# Out:
# Address column found: ADDRESS

# %%
import pandas as pd
import re

# Dictionary mapping abbreviations to full names
abbreviation_map = {
    "St": "Street",
    "Ave": "Avenue",
    "Rd": "Road",
    "Blvd": "Boulevard",
    "Dr": "Drive",
    "Ln": "Lane",
    "Wy": "Way",
    "Pl": "Place"
}

# Function to replace abbreviations safely using regex with word boundaries
def expand_abbreviations(address):
    for abbr, full in abbreviation_map.items():
        address = re.sub(rf'\b{abbr}\b', full, address, flags=re.IGNORECASE)  # Replace full words only
    return address

# Apply function **only to first 10 rows**
df.loc[:9, address_column] = df.loc[:9, address_column].astype(str).apply(expand_abbreviations)

# Print results
print(df.head(10))  # Show first 10 rows to verify
# Out:
#                                    TYPE ADULT_JUVENILE  YEAR  \
# 0                            Possession          Adult  2012
# 1                            Possession          Adult  2012
# 2                            Possession          Adult  2012
# 3                            Possession          Adult  2012
# 4  Possession with intent to distribute          Adult  2012
# 5                            Possession          Adult  2012
# 6  Possession with intent to distribute          Adult  2012
# 7                            Possession          Adult  2012
# 8  Possession with intent to distribute          Adult  2012
# 9                            Possession          Adult  2012
#
#                  DATETIME                              CCN   AGE  \
# 0  2012/01/01 06:00:00+00                 b';\xc8k~\xa4iJ'  20.0
# 1  2012/01/01 06:00:00+00                 b';\xc8k~\xa4iJ'  23.0
# 2  2012/01/01 06:00:00+00           b't6\xa0\xac\xec`\xa4'  46.0
# 3  2012/01/01 09:35:00+00        b'\xbe\x1d\xa7\xf5\xffWx'  30.0
# 4  2012/01/02 19:40:00+00  b'\xbb\xc0\x8e\x94\x81\xac\xcd'  29.0
# 5  2012/01/02 21:47:00+00     b'\x94\xd2y\xaa\xf5\x1a\xcc'  33.0
# 6  2012/01/03 01:30:00+00     b'\x86\xb5?\x7f\xe1\xde\x86'  28.0
# 7  2012/01/03 07:05:00+00             b'\nt\xb3~+\xca\xe6'  36.0
# 8  2012/01/03 22:01:00+00              b'6\x1d\xfa/y\xe0:'  35.0
# 9  2012/01/04 04:15:00+00          b'\x8f.\xc0.\x99\\\xca'  27.0
#
#   OFFENSE_DISTRICT  OFFENSE_PSA  OFFENSE_BLOCKX  OFFENSE_BLOCKY  ...  \
# 0               5D        501.0        399700.0        137900.0  ...
# 1               5D        501.0        399700.0        137900.0  ...
# 2               7D        707.0        399700.0        130600.0  ...
# 3               6D        605.0        403300.0        134500.0  ...
# 4               6D        604.0        406400.0        135300.0  ...
# 5               6D        604.0        406700.0        135700.0  ...
# 6               6D        601.0        404300.0        137400.0  ...
# 7               5D        501.0        399300.0        138000.0  ...
# 8               6D        604.0        406200.0        135000.0  ...
# 9               4D        403.0        397600.0        143000.0  ...
#
#                            ADDRESS ARREST_BLOCKX ARREST_BLOCKY  \
# 0                FLORIDA Avenue NE      401400.0      136900.0
# 1                FLORIDA Avenue NE      401400.0      136900.0
# 2  3300 BLOCK OF BROTHERS Place SE      399700.0      130600.0
# 3      700 BLOCK OF 32ND Street SE           NaN           NaN
# 4        5300 BLOCK OF B Street SE           NaN           NaN
# 5     UNIT BLOCK OF 55TH Street SE      406700.0      135700.0
# 6    3700 BLOCK OF HAYES Street NE      404300.0      137400.0
# 7                  BATES Street NW           NaN           NaN
# 8      400 BLOCK OF 51ST Street SE      406200.0      135000.0
# 9  5400 BLOCK OF GEORGIA Avenue NW      397600.0      143000.0
#
#                     GIS_ID CREATOR                 CREATED EDITOR  \
# 0  MARIJUANA_ARRESTS_12481    JLAY  2022/10/18 21:51:23+00   JLAY
# 1  MARIJUANA_ARRESTS_12482    JLAY  2022/10/18 21:51:23+00   JLAY
# 2  MARIJUANA_ARRESTS_12483    JLAY  2022/10/18 21:51:23+00   JLAY
# 3  MARIJUANA_ARRESTS_12484    JLAY  2022/10/18 21:51:23+00   JLAY
# 4  MARIJUANA_ARRESTS_12485    JLAY  2022/10/18 21:51:23+00   JLAY
# 5  MARIJUANA_ARRESTS_12486    JLAY  2022/10/18 21:51:23+00   JLAY
# 6  MARIJUANA_ARRESTS_12487    JLAY  2022/10/18 21:51:23+00   JLAY
# 7  MARIJUANA_ARRESTS_12488    JLAY  2022/10/18 21:51:23+00   JLAY
# 8  MARIJUANA_ARRESTS_12489    JLAY  2022/10/18 21:51:23+00   JLAY
# 9  MARIJUANA_ARRESTS_12490    JLAY  2022/10/18 21:51:23+00   JLAY
#
#                    EDITED  OBJECTID                                GLOBALID
# 0  2024/05/30 22:47:09+00     12481  {4654D30A-5B56-4E19-8FC2-B19CC723C747}
# 1  2024/05/30 22:47:09+00     12482  {1C0EBA86-27EC-4B8E-8ABB-6EFFF03A0AA2}
# 2  2024/05/30 22:47:09+00     12483  {88080D68-CFA3-41E6-AA69-5DB7F950A134}
# 3  2024/05/30 22:47:09+00     12484  {7769980A-5F36-4B3C-91CF-D1A3A94CE52E}
# 4  2024/05/30 22:47:09+00     12485  {5D5BEE85-DF16-41A1-BB49-0D16D0EE1320}
# 5  2024/05/30 22:47:09+00     12486  {A2B5193B-4D36-4288-B4D1-17AAF06873AE}
# 6  2024/05/30 22:47:09+00     12487  {EC68EFB1-5862-451E-8A20-42138B169026}
# 7  2024/05/30 22:47:09+00     12488  {ED707C36-3967-4E55-BEA5-23793A8CE7FE}
# 8  2024/05/30 22:47:09+00     12489  {2CDBB797-F8BB-4D74-83FD-F83D14A81AA7}
# 9  2024/05/30 22:47:09+00     12490  {61F8EC05-5F88-40AB-BFD8-57824A5A10C4}
#
# [10 rows x 27 columns]

# %%
import pandas as pd
import re

# Dictionary mapping full street names to abbreviations
full_to_abbreviation = {
    "Street": "St",
    "Avenue": "Ave",
    "Road": "Rd",
    "Boulevard": "Blvd",
    "Drive": "Dr",
    "Lane": "Ln",
    "Way": "Wy",
    "Place": "Pl"
}

# Function to abbreviate full street names (case-insensitive)
def abbreviate_address(address):
    for full_name, abbr in full_to_abbreviation.items():
        address = re.sub(rf'\b{full_name}\b', abbr, address, flags=re.IGNORECASE)  # Case-insensitive replacement
    return address

# Apply function **only to the last 10 rows**
df.loc[df.index[-10:], address_column] = df.loc[df.index[-10:], address_column].astype(str).apply(abbreviate_address)

# Print results
print(df.tail(10))  # Show last 10 rows to verify
# Out:
#                                        TYPE ADULT_JUVENILE  YEAR  \
# 14035  Possession with intent to distribute       Juvenile  2023
# 14036  Possession with intent to distribute       Juvenile  2023
# 14037  Possession with intent to distribute       Juvenile  2023
# 14038                            Possession       Juvenile  2023
# 14039  Possession with intent to distribute       Juvenile  2023
# 14040                            Possession       Juvenile  2023
# 14041  Possession with intent to distribute       Juvenile  2023
# 14042  Possession with intent to distribute       Juvenile  2023
# 14043                          Distribution       Juvenile  2023
# 14044  Possession with intent to distribute       Juvenile  2023
#
#                      DATETIME  CCN  AGE OFFENSE_DISTRICT  OFFENSE_PSA  \
# 14035  2023/10/12 04:00:00+00  NaN  NaN               4D        403.0
# 14036  2023/10/12 04:00:00+00  NaN  NaN               4D        403.0
# 14037  2023/10/13 04:00:00+00  NaN  NaN               6D        607.0
# 14038  2023/10/26 04:00:00+00  NaN  NaN               3D        303.0
# 14039  2023/10/26 04:00:00+00  NaN  NaN               3D        303.0
# 14040  2023/10/26 04:00:00+00  NaN  NaN               3D        303.0
# 14041  2023/12/07 05:00:00+00  NaN  NaN               6D        601.0
# 14042  2023/12/16 05:00:00+00  NaN  NaN               6D        608.0
# 14043  2023/12/19 05:00:00+00  NaN  NaN               7D        708.0
# 14044  2023/12/30 05:00:00+00  NaN  NaN               6D        607.0
#
#        OFFENSE_BLOCKX  OFFENSE_BLOCKY  ...                  ADDRESS  \
# 14035             NaN             NaN  ...                      nan
# 14036             NaN             NaN  ...            3322 BLAKE ST
# 14037             NaN             NaN  ...           3323 PARK BLVD
# 14038             NaN             NaN  ...             24 ASHTON DR
# 14039             NaN             NaN  ...               4 TAHOE LN
# 14040             NaN             NaN  ...           215 MANSION RD
# 14041             NaN             NaN  ...     315 THOROUGHBRED AVE
# 14042             NaN             NaN  ...             204 DORIS Pl
# 14043             NaN             NaN  ...  MARTIN LUTHER KING BLVD
# 14044             NaN             NaN  ...             8 WILLIOW WY
#
#       ARREST_BLOCKX ARREST_BLOCKY                   GIS_ID CREATOR  \
# 14035           NaN           NaN  MARIJUANA_ARRESTS_27659    JLAY
# 14036           NaN           NaN  MARIJUANA_ARRESTS_27660    JLAY
# 14037           NaN           NaN  MARIJUANA_ARRESTS_27661    JLAY
# 14038           NaN           NaN  MARIJUANA_ARRESTS_27662    JLAY
# 14039           NaN           NaN  MARIJUANA_ARRESTS_27663    JLAY
# 14040           NaN           NaN  MARIJUANA_ARRESTS_27664    JLAY
# 14041           NaN           NaN  MARIJUANA_ARRESTS_27665    JLAY
# 14042           NaN           NaN  MARIJUANA_ARRESTS_27666    JLAY
# 14043           NaN           NaN  MARIJUANA_ARRESTS_27667    JLAY
# 14044           NaN           NaN  MARIJUANA_ARRESTS_27668    JLAY
#
#                       CREATED EDITOR                  EDITED  OBJECTID  \
# 14035  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27659
# 14036  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27660
# 14037  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27661
# 14038  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27662
# 14039  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27663
# 14040  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27664
# 14041  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27665
# 14042  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27666
# 14043  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27667
# 14044  2024/05/30 22:31:49+00   JLAY  2024/05/30 22:47:09+00     27668
#
#                                      GLOBALID
# 14035  {42A0F7D3-70F7-47DA-8627-F63118B70FFA}
# 14036  {AB159AE0-90A3-4CAF-B31B-BDBC7FE3536A}
# 14037  {8173EE24-AB5E-4E11-A783-9AFB9801463E}
# 14038  {9DE72BC0-07D4-42B0-A17B-1940CC92C4B7}
# 14039  {AE8BC07E-9154-4FA5-9B8D-6C439C8513FE}
# 14040  {D0CABACE-FAE3-4F40-BFF2-4D698CFEDAB1}
# 14041  {547A3AD2-809C-46F8-B251-2BEB5C121C7A}
# 14042  {C6BC98AA-B9F2-4E81-954B-0D04D1FF24C9}
# 14043  {3A441C0C-C10E-48F5-83A0-806D22A046CF}
# 14044  {6AE10201-674B-4198-BB78-EA83007AE6A4}
#
# [10 rows x 27 columns]

# %%
import pandas as pd
import re

# Dictionary mapping full street names to abbreviations
full_to_abbreviation = {
    "Street": "St",
    "Avenue": "Ave",
    "Road": "Rd",
    "Boulevard": "Blvd",
    "Drive": "Dr",
    "Lane": "Ln",
    "Way": "Wy",
    "Place": "Pl"
}

# Function to abbreviate full street names (case-insensitive)
def abbreviate_address(address):
    for full_name, abbr in full_to_abbreviation.items():
        address = re.sub(rf'\b{full_name}\b', abbr, address, flags=re.IGNORECASE)  # Case-insensitive replacement
    return address

# Apply function to the entire address column
df[address_column] = df[address_column].astype(str).apply(abbreviate_address)

# Print results
print(df[address_column].head(10))  # Show first 10 updated addresses
# Out:
# 0                  FLORIDA Ave NE
# 1                  FLORIDA Ave NE
# 2    3300 BLOCK OF BROTHERS Pl SE
# 3         700 BLOCK OF 32ND St SE
# 4           5300 BLOCK OF B St SE
# 5        UNIT BLOCK OF 55TH St SE
# 6       3700 BLOCK OF HAYES St NE
# 7                     BATES St NW
# 8         400 BLOCK OF 51ST St SE
# 9    5400 BLOCK OF GEORGIA Ave NW
# Name: ADDRESS, dtype: object

# %%
full_street_rows = df[df[address_column].str.contains('|'.join(full_to_abbreviation.keys()), case=False, regex=True)]
print(f"✅ After reprocessing, the column now has an abbreviated street address format. However, there are {len(full_street_rows)} addresses that are not updating due to typos, spacing, and unrecognizeable characters such as quotations, symbols etc. Consider updating these anomalies before using data set.")
print(f"If there are anomolies to the address column, examples will appear below:")
print(full_street_rows[[address_column]].head(10))  # Show sample of unchanged rows
# Out:
# ✅ After reprocessing, the column now has an abbreviated street address format. However, there are 482 addresses that are not updating due to typos, spacing, and unrecognizeable characters such as quotations, symbols etc. Consider updating these anomalies before using data set.
# If there are anomolies to the address column, examples will appear below:
#                                             ADDRESS
# 466                                    47TH PLACENE
# 700                       600 BLOCK OF 46TH PLACESE
# 751             3300 BLOCK OF EAST CAPITOL STREETNE
# 783                  1000 BLOCK OF EASTERN AVENUENE
# 799                      200 BLOCK OF 34TH STREETNE
# 847                      1200 BLOCK OF 49TH PLACENE
# 852   4200 BLOCK OF NANNIE HELEN BURROUGHS AVENUENE
# 902                SUITLAND PARKWAY EB / STANTON RD
# 1164                                     R STREETNW
# 1206                     300 BLOCK OF 50TH STREETNE

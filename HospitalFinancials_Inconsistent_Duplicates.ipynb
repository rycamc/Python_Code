# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

path = '/content/drive/MyDrive/selected-file_2012_2017_machinereadable.csv'

import pandas as pd
df = pd.read_csv(path)
pd.set_option('display.max_columns', None)
df
# Out:
# Mounted at /content/drive
# <ipython-input-1-1196270933>:9: DtypeWarning: Columns (20,23,28,29,30,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
#            FAC_NO                   FAC_NAME   BEG_DATE   END_DATE  DAY_PER  \
# 0       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 1       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 2       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 3       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 4       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# ...           ...                        ...        ...        ...      ...
# 578345  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578346  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578347  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578348  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578349  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
#
#           DATA_IND              AUDIT_IND   COUNTY  HSA  HFPA  TYPE_CNTRL  \
# 0          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 1          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 2          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 3          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 4          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# ...            ...                    ...      ...  ...   ...         ...
# 578345  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578346  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578347  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578348  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578349  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
#
#        TYPE_CARE   TYPE_HOSP TEACH_RURL           PHONE              ADDRESS  \
# 0        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 1        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 2        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 3        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 4        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# ...          ...         ...        ...             ...                  ...
# 578345   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578346   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578347   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578348   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578349   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
#
#               CITY    ZIP_CODE                  CEO CEO_TITLE  \
# 0          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 1          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 2          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 3          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 4          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# ...            ...         ...                  ...       ...
# 578345  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578346  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578347  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578348  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578349  MARYSVILLE       95901        GINO PATRIZIO       CEO
#
#                        WEB_SITE                                OWNER  \
# 0       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 1       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 2       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 3       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 4       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# ...                         ...                                  ...
# 578345             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578346             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578347             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578348             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578349             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
#
#               RPT_PREP                     ORG_NAME  ER_DESIG MCAR_PRO#  \
# 0       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 1       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 2       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 3       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 4       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# ...                ...                          ...       ...       ...
# 578345     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578346     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578347     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578348     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578349     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
#
#         MCAL_PRO#  REG_MCAL# BED_LIC BED_AVL BED_STF       Variable    Amount  \
# 0       HSC00211F  ZZR00211F     161     161     161   DAY_ MCAR_TR   12330.0
# 1       HSC00211F  ZZR00211F     161     161     161    DAY_MCAR_MC     885.0
# 2       HSC00211F  ZZR00211F     161     161     161    DAY_MCAL_TR   13093.0
# 3       HSC00211F  ZZR00211F     161     161     161  DAY_ MCAL_ MC    1786.0
# 4       HSC00211F  ZZR00211F     161     161     161       DAY_CNTY       0.0
# ...           ...        ...     ...     ...     ...            ...       ...
# 578345  172008835  ZZR00133F     221     219     152       PD_HR_ED       0.0
# 578346  172008835  ZZR00133F     221     219     152      PD_HR_GEN  475235.0
# 578347  172008835  ZZR00133F     221     219     152      PD_HR_FIS  186036.0
# 578348  172008835  ZZR00133F     221     219     152      PD_HR_ADM  367425.0
# 578349  172008835  ZZR00133F     221     219     152      PD_HR_NON       0.0
#
#        WEB-SITE ORG-NAME
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 578345      NaN      NaN
# 578346      NaN      NaN
# 578347      NaN      NaN
# 578348      NaN      NaN
# 578349      NaN      NaN
#
# [578350 rows x 35 columns]

# %%
import pandas as pd

def duplicate_last_rows(df, n=50):
    """
    Duplicates the last n rows of a DataFrame and appends them to the end.

    Args:
        df (pd.DataFrame): The input DataFrame.
        n (int): The number of last rows to duplicate.

    Returns:
        pd.DataFrame: A new DataFrame with the duplicated rows appended.
    """
    if n > len(df):
        raise ValueError("n cannot be larger than the DataFrame length")

    last_rows = df.tail(n)
    df_duplicated = pd.concat([df, last_rows], ignore_index=True)
    return df_duplicated

if __name__ == '__main__':
  df_duplicated = duplicate_last_rows(df)
  df = df_duplicated
df
# Out:
#            FAC_NO                   FAC_NAME   BEG_DATE   END_DATE  DAY_PER  \
# 0       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 1       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 2       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 3       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 4       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# ...           ...                        ...        ...        ...      ...
# 578395  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578396  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578397  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578398  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578399  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
#
#           DATA_IND              AUDIT_IND   COUNTY  HSA  HFPA  TYPE_CNTRL  \
# 0          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 1          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 2          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 3          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 4          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# ...            ...                    ...      ...  ...   ...         ...
# 578395  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578396  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578397  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578398  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578399  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
#
#        TYPE_CARE   TYPE_HOSP TEACH_RURL           PHONE              ADDRESS  \
# 0        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 1        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 2        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 3        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 4        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# ...          ...         ...        ...             ...                  ...
# 578395   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578396   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578397   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578398   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578399   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
#
#               CITY    ZIP_CODE                  CEO CEO_TITLE  \
# 0          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 1          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 2          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 3          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 4          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# ...            ...         ...                  ...       ...
# 578395  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578396  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578397  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578398  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578399  MARYSVILLE       95901        GINO PATRIZIO       CEO
#
#                        WEB_SITE                                OWNER  \
# 0       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 1       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 2       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 3       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 4       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# ...                         ...                                  ...
# 578395             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578396             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578397             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578398             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578399             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
#
#               RPT_PREP                     ORG_NAME  ER_DESIG MCAR_PRO#  \
# 0       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 1       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 2       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 3       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 4       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# ...                ...                          ...       ...       ...
# 578395     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578396     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578397     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578398     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578399     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
#
#         MCAL_PRO#  REG_MCAL# BED_LIC BED_AVL BED_STF       Variable    Amount  \
# 0       HSC00211F  ZZR00211F     161     161     161   DAY_ MCAR_TR   12330.0
# 1       HSC00211F  ZZR00211F     161     161     161    DAY_MCAR_MC     885.0
# 2       HSC00211F  ZZR00211F     161     161     161    DAY_MCAL_TR   13093.0
# 3       HSC00211F  ZZR00211F     161     161     161  DAY_ MCAL_ MC    1786.0
# 4       HSC00211F  ZZR00211F     161     161     161       DAY_CNTY       0.0
# ...           ...        ...     ...     ...     ...            ...       ...
# 578395  172008835  ZZR00133F     221     219     152       PD_HR_ED       0.0
# 578396  172008835  ZZR00133F     221     219     152      PD_HR_GEN  475235.0
# 578397  172008835  ZZR00133F     221     219     152      PD_HR_FIS  186036.0
# 578398  172008835  ZZR00133F     221     219     152      PD_HR_ADM  367425.0
# 578399  172008835  ZZR00133F     221     219     152      PD_HR_NON       0.0
#
#        WEB-SITE ORG-NAME
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 578395      NaN      NaN
# 578396      NaN      NaN
# 578397      NaN      NaN
# 578398      NaN      NaN
# 578399      NaN      NaN
#
# [578400 rows x 35 columns]

# %%
import matplotlib.pyplot as plt
duplicates = df[df.duplicated(keep=False)]
  # Create a DataFrame to represent the duplicated rows and its indices
duplicated_rows = pd.DataFrame({
    'duplicated': df.duplicated(keep=False),
    'row': range(1, len(df) + 1)
    })
duplicated_rows = duplicated_rows[duplicated_rows['duplicated']]

# Plot vertical lines at the index of the duplicated rows
plt.figure()
plt.vlines(duplicated_rows['row'], ymin=0, ymax=1, colors='blue')
plt.gca().invert_xaxis()
plt.title('Indexes of duplicated rows')
plt.xlabel('Row index')
plt.ylabel('Duplicated')
plt.show()

# Identify duplicate rows
duplicate_rows = df.duplicated()

# Count the number of duplicate rows
num_duplicates = duplicate_rows.sum()
print(f"Number of duplicate rows: {num_duplicates}. This data is inconsistent.")
row_count = len(df)
print(f"Row Count with duplicates: {row_count}.")
# Out:
# Number of duplicate rows: 50. This data is inconsistent.
# Row Count with duplicates: 578400.

# %%
def remove_duplicate_rows(df, subset_columns=None, keep='first'):
    """
    Removes duplicate rows from a Pandas DataFrame.

    Args:
        df (pd.DataFrame): The input DataFrame.
        subset_columns (list, optional): List of column names to consider for identifying duplicates.
            If None, all columns will be considered. Defaults to None.
        keep (str, optional): Specifies which duplicates to keep.
            'first': Keep the first occurrence.
            'last': Keep the last occurrence.
            False: Drop all duplicates. Defaults to 'first'.

    Returns:
        pd.DataFrame: A new DataFrame with duplicate rows removed.
    """

    df_no_duplicates = df.drop_duplicates(subset=subset_columns, keep=keep)
    return df_no_duplicates

if __name__ == '__main__':
  df_no_duplicates_all = remove_duplicate_rows(df)
  row_count = len(df_no_duplicates_all)
  print(f"Row Count: {row_count}.")
  print()

duplicate_count = df_no_duplicates_all.duplicated().sum()

# Print the count of duplicates
print(f"Number of duplicate rows: {duplicate_count}. This data is consistent.")
print()
print("DataFrame with duplicates removed based on all columns:\n", df_no_duplicates_all)
# Out:
# Row Count: 578350.
#
# Number of duplicate rows: 0. This data is consistent.
#
# DataFrame with duplicates removed based on all columns:
#             FAC_NO                   FAC_NAME   BEG_DATE   END_DATE  DAY_PER  \
# 0       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 1       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 2       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 3       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# 4       106010735           ALAMEDA HOSPITAL  01JUL2011  30JUN2012      366
# ...           ...                        ...        ...        ...      ...
# 578345  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578346  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578347  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578348  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
# 578349  106580996  RIDEOUT MEMORIAL HOSPITAL  01JUL2016  30JUN2017      365
#
#           DATA_IND              AUDIT_IND   COUNTY  HSA  HFPA  TYPE_CNTRL  \
# 0          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 1          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 2          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 3          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# 4          Audited  Incl. Ind. Audit Adj.  Alameda    5   417    District
# ...            ...                    ...      ...  ...   ...         ...
# 578345  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578346  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578347  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578348  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
# 578349  In Process  Incl. Ind. Audit Adj.     Yuba    2   227  Non-Profit
#
#        TYPE_CARE   TYPE_HOSP TEACH_RURL           PHONE              ADDRESS  \
# 0        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 1        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 2        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 3        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# 4        General  Comparable        NaN  (510) 522-3700  2070 CLINTON AVENUE
# ...          ...         ...        ...             ...                  ...
# 578345   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578346   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578347   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578348   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
# 578349   General  Comparable        NaN    530-749-4545    726 FOURTH STREET
#
#               CITY    ZIP_CODE                  CEO CEO_TITLE  \
# 0          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 1          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 2          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 3          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# 4          ALAMEDA  94501-4397  DEBORAH E. STEBBINS       CEO
# ...            ...         ...                  ...       ...
# 578345  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578346  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578347  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578348  MARYSVILLE       95901        GINO PATRIZIO       CEO
# 578349  MARYSVILLE       95901        GINO PATRIZIO       CEO
#
#                        WEB_SITE                                OWNER  \
# 0       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 1       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 2       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 3       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# 4       WWW.ALAMEDAHOSPITAL.ORG  CITY OF ALAMEDA HEALTHCARE DISTRICT
# ...                         ...                                  ...
# 578345             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578346             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578347             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578348             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
# 578349             WWW.FRHG.ORG         FREMONT RIDEOUT HEALTH GROUP
#
#               RPT_PREP                     ORG_NAME  ER_DESIG MCAR_PRO#  \
# 0       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 1       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 2       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 3       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# 4       CARLOS JIMENEZ  PACIFIC HOSPITAL MANAGEMENT       0.0   05-0211
# ...                ...                          ...       ...       ...
# 578345     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578346     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578347     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578348     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
# 578349     ERIC KELLAR       TOYON ASSOCIATES, INC.       3.0   05-0133
#
#         MCAL_PRO#  REG_MCAL# BED_LIC BED_AVL BED_STF       Variable    Amount  \
# 0       HSC00211F  ZZR00211F     161     161     161   DAY_ MCAR_TR   12330.0
# 1       HSC00211F  ZZR00211F     161     161     161    DAY_MCAR_MC     885.0
# 2       HSC00211F  ZZR00211F     161     161     161    DAY_MCAL_TR   13093.0
# 3       HSC00211F  ZZR00211F     161     161     161  DAY_ MCAL_ MC    1786.0
# 4       HSC00211F  ZZR00211F     161     161     161       DAY_CNTY       0.0
# ...           ...        ...     ...     ...     ...            ...       ...
# 578345  172008835  ZZR00133F     221     219     152       PD_HR_ED       0.0
# 578346  172008835  ZZR00133F     221     219     152      PD_HR_GEN  475235.0
# 578347  172008835  ZZR00133F     221     219     152      PD_HR_FIS  186036.0
# 578348  172008835  ZZR00133F     221     219     152      PD_HR_ADM  367425.0
# 578349  172008835  ZZR00133F     221     219     152      PD_HR_NON       0.0
#
#        WEB-SITE ORG-NAME
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 578345      NaN      NaN
# 578346      NaN      NaN
# 578347      NaN      NaN
# 578348      NaN      NaN
# 578349      NaN      NaN
#
# [578350 rows x 35 columns]

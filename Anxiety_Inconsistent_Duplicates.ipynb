# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

path = '/content/drive/MyDrive/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv'

import pandas as pd
df = pd.read_csv(path)
pd.set_option('display.max_columns', None)
df
# Out:
# Mounted at /content/drive
#                                                Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 1                        Symptoms of Depressive Disorder             By Age
# 2                        Symptoms of Depressive Disorder             By Age
# 3                        Symptoms of Depressive Disorder             By Age
# 4                        Symptoms of Depressive Disorder             By Age
# ...                                                  ...                ...
# 16789  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16790  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16791  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16792  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16793  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
#                State       Subgroup Phase  Time Period      Time Period Label  \
# 0      United States  United States     1            1   Apr 23 - May 5, 2020
# 1      United States  18 - 29 years     1            1   Apr 23 - May 5, 2020
# 2      United States  30 - 39 years     1            1   Apr 23 - May 5, 2020
# 3      United States  40 - 49 years     1            1   Apr 23 - May 5, 2020
# 4      United States  50 - 59 years     1            1   Apr 23 - May 5, 2020
# ...              ...            ...   ...          ...                    ...
# 16789       Virginia       Virginia   4.2           72  Aug 20 - Sep 16, 2024
# 16790     Washington     Washington   4.2           72  Aug 20 - Sep 16, 2024
# 16791  West Virginia  West Virginia   4.2           72  Aug 20 - Sep 16, 2024
# 16792      Wisconsin      Wisconsin   4.2           72  Aug 20 - Sep 16, 2024
# 16793        Wyoming        Wyoming   4.2           72  Aug 20 - Sep 16, 2024
#
#       Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0                 04/23/2020           05/05/2020   23.5    22.7     24.3
# 1                 04/23/2020           05/05/2020   32.7    30.2     35.2
# 2                 04/23/2020           05/05/2020   25.7    24.1     27.3
# 3                 04/23/2020           05/05/2020   24.8    23.3     26.2
# 4                 04/23/2020           05/05/2020   23.2    21.5     25.0
# ...                      ...                  ...    ...     ...      ...
# 16789             08/20/2024           09/16/2024   20.8    17.4     24.5
# 16790             08/20/2024           09/16/2024   19.9    17.4     22.6
# 16791             08/20/2024           09/16/2024   26.3    21.5     31.4
# 16792             08/20/2024           09/16/2024   17.0    13.4     21.2
# 16793             08/20/2024           09/16/2024   25.6    19.3     32.8
#
#       Confidence Interval Quartile Range
# 0             22.7 - 24.3            NaN
# 1             30.2 - 35.2            NaN
# 2             24.1 - 27.3            NaN
# 3             23.3 - 26.2            NaN
# 4             21.5 - 25.0            NaN
# ...                   ...            ...
# 16789         17.4 - 24.5      19.5-21.5
# 16790         17.4 - 22.6      19.5-21.5
# 16791         21.5 - 31.4      23.1-27.8
# 16792         13.4 - 21.2      16.6-19.4
# 16793         19.3 - 32.8      23.1-27.8
#
# [16794 rows x 14 columns]

# %%
import pandas as pd

def duplicate_last_rows(df, n=50):
    """
    Duplicates the last n rows of a DataFrame and appends them to the end.

    Args:
        df (pd.DataFrame): The input DataFrame.
        n (int): The number of last rows to duplicate.

    Returns:
        pd.DataFrame: A new DataFrame with the duplicated rows appended.
    """
    if n > len(df):
        raise ValueError("n cannot be larger than the DataFrame length")

    last_rows = df.tail(n)
    df_duplicated = pd.concat([df, last_rows], ignore_index=True)
    return df_duplicated

if __name__ == '__main__':
  df_duplicated = duplicate_last_rows(df)
  df = df_duplicated
df
# Out:
#                                                Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 1                        Symptoms of Depressive Disorder             By Age
# 2                        Symptoms of Depressive Disorder             By Age
# 3                        Symptoms of Depressive Disorder             By Age
# 4                        Symptoms of Depressive Disorder             By Age
# ...                                                  ...                ...
# 16839  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16840  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16841  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16842  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16843  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
#                State       Subgroup Phase  Time Period      Time Period Label  \
# 0      United States  United States     1            1   Apr 23 - May 5, 2020
# 1      United States  18 - 29 years     1            1   Apr 23 - May 5, 2020
# 2      United States  30 - 39 years     1            1   Apr 23 - May 5, 2020
# 3      United States  40 - 49 years     1            1   Apr 23 - May 5, 2020
# 4      United States  50 - 59 years     1            1   Apr 23 - May 5, 2020
# ...              ...            ...   ...          ...                    ...
# 16839       Virginia       Virginia   4.2           72  Aug 20 - Sep 16, 2024
# 16840     Washington     Washington   4.2           72  Aug 20 - Sep 16, 2024
# 16841  West Virginia  West Virginia   4.2           72  Aug 20 - Sep 16, 2024
# 16842      Wisconsin      Wisconsin   4.2           72  Aug 20 - Sep 16, 2024
# 16843        Wyoming        Wyoming   4.2           72  Aug 20 - Sep 16, 2024
#
#       Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0                 04/23/2020           05/05/2020   23.5    22.7     24.3
# 1                 04/23/2020           05/05/2020   32.7    30.2     35.2
# 2                 04/23/2020           05/05/2020   25.7    24.1     27.3
# 3                 04/23/2020           05/05/2020   24.8    23.3     26.2
# 4                 04/23/2020           05/05/2020   23.2    21.5     25.0
# ...                      ...                  ...    ...     ...      ...
# 16839             08/20/2024           09/16/2024   20.8    17.4     24.5
# 16840             08/20/2024           09/16/2024   19.9    17.4     22.6
# 16841             08/20/2024           09/16/2024   26.3    21.5     31.4
# 16842             08/20/2024           09/16/2024   17.0    13.4     21.2
# 16843             08/20/2024           09/16/2024   25.6    19.3     32.8
#
#       Confidence Interval Quartile Range
# 0             22.7 - 24.3            NaN
# 1             30.2 - 35.2            NaN
# 2             24.1 - 27.3            NaN
# 3             23.3 - 26.2            NaN
# 4             21.5 - 25.0            NaN
# ...                   ...            ...
# 16839         17.4 - 24.5      19.5-21.5
# 16840         17.4 - 22.6      19.5-21.5
# 16841         21.5 - 31.4      23.1-27.8
# 16842         13.4 - 21.2      16.6-19.4
# 16843         19.3 - 32.8      23.1-27.8
#
# [16844 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
duplicates = df[df.duplicated(keep=False)]
  # Create a DataFrame to represent the duplicated rows and its indices
duplicated_rows = pd.DataFrame({
    'duplicated': df.duplicated(keep=False),
    'row': range(1, len(df) + 1)
    })
duplicated_rows = duplicated_rows[duplicated_rows['duplicated']]

# Plot vertical lines at the index of the duplicated rows
plt.figure()
plt.vlines(duplicated_rows['row'], ymin=0, ymax=1, colors='blue')
plt.gca().invert_xaxis()
plt.title('Indexes of duplicated rows')
plt.xlabel('Row index')
plt.ylabel('Duplicated')
plt.show()

# Identify duplicate rows
duplicate_rows = df.duplicated()

# Count the number of duplicate rows
num_duplicates = duplicate_rows.sum()
print(f"Number of duplicate rows: {num_duplicates}. This data is inconsistent.")
row_count = len(df)
print(f"Row Count with duplicates: {row_count}.")
# Out:
# Number of duplicate rows: 50. This data is inconsistent.
# Row Count with duplicates: 16844.

# %%
def remove_duplicate_rows(df, subset_columns=None, keep='first'):
    """
    Removes duplicate rows from a Pandas DataFrame.

    Args:
        df (pd.DataFrame): The input DataFrame.
        subset_columns (list, optional): List of column names to consider for identifying duplicates.
            If None, all columns will be considered. Defaults to None.
        keep (str, optional): Specifies which duplicates to keep.
            'first': Keep the first occurrence.
            'last': Keep the last occurrence.
            False: Drop all duplicates. Defaults to 'first'.

    Returns:
        pd.DataFrame: A new DataFrame with duplicate rows removed.
    """

    df_no_duplicates = df.drop_duplicates(subset=subset_columns, keep=keep)
    return df_no_duplicates

if __name__ == '__main__':
  df_no_duplicates_all = remove_duplicate_rows(df)
  row_count = len(df_no_duplicates_all)
  print(f"Row Count: {row_count}.")
  print()

duplicate_count = df_no_duplicates_all.duplicated().sum()

# Print the count of duplicates
print(f"Number of duplicate rows: {duplicate_count}. This data is consistent.")
print()
print("DataFrame with duplicates removed based on all columns:\n", df_no_duplicates_all)
# Out:
# Row Count: 16794.
#
# Number of duplicate rows: 0. This data is consistent.
#
# DataFrame with duplicates removed based on all columns:
#                                                 Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 1                        Symptoms of Depressive Disorder             By Age
# 2                        Symptoms of Depressive Disorder             By Age
# 3                        Symptoms of Depressive Disorder             By Age
# 4                        Symptoms of Depressive Disorder             By Age
# ...                                                  ...                ...
# 16789  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16790  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16791  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16792  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 16793  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
#                State       Subgroup Phase  Time Period      Time Period Label  \
# 0      United States  United States     1            1   Apr 23 - May 5, 2020
# 1      United States  18 - 29 years     1            1   Apr 23 - May 5, 2020
# 2      United States  30 - 39 years     1            1   Apr 23 - May 5, 2020
# 3      United States  40 - 49 years     1            1   Apr 23 - May 5, 2020
# 4      United States  50 - 59 years     1            1   Apr 23 - May 5, 2020
# ...              ...            ...   ...          ...                    ...
# 16789       Virginia       Virginia   4.2           72  Aug 20 - Sep 16, 2024
# 16790     Washington     Washington   4.2           72  Aug 20 - Sep 16, 2024
# 16791  West Virginia  West Virginia   4.2           72  Aug 20 - Sep 16, 2024
# 16792      Wisconsin      Wisconsin   4.2           72  Aug 20 - Sep 16, 2024
# 16793        Wyoming        Wyoming   4.2           72  Aug 20 - Sep 16, 2024
#
#       Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0                 04/23/2020           05/05/2020   23.5    22.7     24.3
# 1                 04/23/2020           05/05/2020   32.7    30.2     35.2
# 2                 04/23/2020           05/05/2020   25.7    24.1     27.3
# 3                 04/23/2020           05/05/2020   24.8    23.3     26.2
# 4                 04/23/2020           05/05/2020   23.2    21.5     25.0
# ...                      ...                  ...    ...     ...      ...
# 16789             08/20/2024           09/16/2024   20.8    17.4     24.5
# 16790             08/20/2024           09/16/2024   19.9    17.4     22.6
# 16791             08/20/2024           09/16/2024   26.3    21.5     31.4
# 16792             08/20/2024           09/16/2024   17.0    13.4     21.2
# 16793             08/20/2024           09/16/2024   25.6    19.3     32.8
#
#       Confidence Interval Quartile Range
# 0             22.7 - 24.3            NaN
# 1             30.2 - 35.2            NaN
# 2             24.1 - 27.3            NaN
# 3             23.3 - 26.2            NaN
# 4             21.5 - 25.0            NaN
# ...                   ...            ...
# 16789         17.4 - 24.5      19.5-21.5
# 16790         17.4 - 22.6      19.5-21.5
# 16791         21.5 - 31.4      23.1-27.8
# 16792         13.4 - 21.2      16.6-19.4
# 16793         19.3 - 32.8      23.1-27.8
#
# [16794 rows x 14 columns]
